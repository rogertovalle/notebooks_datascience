# %% [markdown]
# # Limpieza de datos - Proyecto W

# %% [markdown]
# El objetivo de este notebook es limpiar los datos de las bases de datos del año 2019 y 2020 del proyecto W, las cuales
# provienen de diferentes archivos de Excel, de tal manera que las dos fuentes de datos puedan combinarse en un solo archivo, el cuál sera con el cual se migrará la informaación a la base de datos de la aplicación 'Proyecto W' diseñada para gestionar
# esta información a partir del momento de la migración. La clave está, en que, la información debe coincidir de tal manera que
# la misma pueda ser visualizada sin problema en la aplicación.
#
# Este notebook se desarrollará en tres partes:
#
# <b>Parte 1:</b>Sincronizando cantidad de features y nombres de los features.
#
# <b>Parte 2:</b> Revisión de tipos de datos de los features para garantizar que coincidan con la base de datos de la aplicación a la cuál se van a migrar.
#
# <b>Parte 3:</b> Garantizar que existan valores únicos para los features categorícos, y que los mismos sean coincidentes con los
# estandarizados en la aplicación.
#
# <b>Finalización:</b> En esta parte se creará el archivo de Excel en el cuál se tendrá la base de datos limpia y lista
# para realizar la migración. En este punto el Notebook termina.
#
# Como resultado de este ejercicio, se tendran los siguientes productos:
#
# a. Archivo en Excel (xlsx) que contendrá una base de datos limpia lista para migrar.
#
# b. Archivo en Excel (xlsx) para cada feature que requiera verificarse manualmente, que contendrán registros que requieren ser revisados, para garantizar una óptima migración.
#
# Como insumos para este ejercicio se tiene:
#
# a. Base de datos 2019, llamada chubb_2019.xlsx
#
# b. Base de datos 2020, llamada chubb_2020.xlsx
#
# c. Diccionario de columnas chubb, llamado diccionario_columnas_chubb.csv, el cuál contendrá el nombre de los campos de la aplicación así como el tipo de datos que deberá contener. Este diccionario de manera simultanea con el desarrollo de la parte 1 del ejercicio.

# %%
#Importo librerias base con las cuales se realizará tratamiento de datos.
import numpy as np
import pandas as pd

# %%
#Cargo la información contenida en los archivos de excel como un dataframe.
df_w_2019 = pd.read_excel(open('chubb_2019.xlsx', 'rb'),sheet_name=1)
df_w_2020 = pd.read_excel(open('chubb_2020.xlsx', 'rb'),sheet_name=1)

# %%
#Exploramos la forma de estos dataframes, como primer indicador de poder unir los dos datasets en un sólo archivo.
print(df_w_2019.shape)
print(df_w_2020.shape)
# Out:
# (1208, 51)
# (501, 51)

# %% [markdown]
# ## PARTE I - Sincronizando cantidad de features y nombres de los features.
#
# Objetivos:
# 1. Establecer un número de features coincidente, que permita combinar la información en un sólo archivo.
# 1. Establecer nombres de columnas uniformes.

# %%
#Genero un dataframe que me permita comparar visualmente si las columnas están organizadas de manera simetrica
columns_2019 = pd.DataFrame(df_w_2019.columns)
columns_2020 = pd.DataFrame(df_w_2020.columns)
columns_2020['2019'] = columns_2019[0]
columns_2020
# Out:
#                                          0  \
# 0                                     ITEM
# 1                      CANTIDAD DE POLIZAS
# 2                                No POLIZA
# 3                                No ZONIC
# 4                        CIUDAD OCURRENCIA
# 5                             DEPARTAMENTO
# 6                                DIRECCION
# 7                                ASEGURADO
# 8                     CEDULA DE CIUDADANIA
# 9                                 PRODUCTO
# 10                              CATEGORIA
# 11                               SINIESTRO
# 12                      FECHA DE SINIESTRO
# 13      FECHA DE CONFIRMACIÓN DE SINIESTRO
# 14                    FECHA AVISO INGETECH
# 15  FECHA DE APROBACIÓN DE OBJECIÓN Y PAGO
# 16                     FECHA DE DEFINICIÓN
# 17      FECHA DE FORMALIZACIÓN DEL RECLAMO
# 18                                SEMÁFORO
# 19                                    MES
# 20                     FECHA DE INSPECCION
# 21             FECHA ENTREGA INFORME FINAL
# 22               FECHA ENVÍO INFORME FINAL
# 23                            RESPONSABLE
# 24                           VALOR RECLAMO
# 25                           VALOR RESERVA
# 26                      VALOR A INDEMNIZAR
# 27                              HONORARIOS
# 28                                   CAUSA
# 29                               COBERTURA
# 30                                  ESTADO
# 31                           OBSERVACION 1
# 32                           OBSERVACION 2
# 33                                   NOTAS
# 34                                 FACTURA
# 35                               INSPECTOR
# 36                               AJUSTADOR
# 37                      NUMERO DE TELEFONO
# 38                           CO-EXISTENCIA
# 39                                  BIENES
# 40                                  HECHOS
# 41                                 CREDITO
# 42                          VIGENCIA DESDE
# 43                          VIGENCIA HASTA
# 44                          RAZON OBJECIÓN
# 45                        ENTIDAD BANCARIA
# 46                         CUENTA BANCARIA
# 47                           FORMA DE PAGO
# 48                         RECONSIDERACIÓN
# 49                      FECHA DE RESPUESTA
# 50                     2020-03-09 00:00:00
#
#                                       2019
# 0                                        Q
# 1                                     ITEM
# 2                      CANTIDAD DE POLIZAS
# 3                                No POLIZA
# 4                                 No ZONIC
# 5                        CIUDAD OCURRENCIA
# 6                             DEPARTAMENTO
# 7                                DIRECCION
# 8                                ASEGURADO
# 9                             CC ASEGURADO
# 10                                PRODUCTO
# 11                              CATEGORIA
# 12                               SINIESTRO
# 13                      FECHA DE SINIESTRO
# 14      FECHA DE CONFIRMACIÓN DE SINIESTRO
# 15                    FECHA AVISO INGETECH
# 16  FECHA DE APROBACIÓN DE OBJECIÓN Y PAGO
# 17                     FECHA DE DEFINICIÓN
# 18      FECHA DE FORMALIZACIÓN DEL RECLAMO
# 19                                SEMÁFORO
# 20                                    MES
# 21                     FECHA DE INSPECCION
# 22             FECHA ENTREGA INFORME FINAL
# 23               FECHA ENVÍO INFORME FINAL
# 24                            RESPONSABLE
# 25                           VALOR RECLAMO
# 26              VALOR RESERVA (PAGO TOTAL)
# 27                      VALOR A INDEMNIZAR
# 28                              HONORARIOS
# 29                                   CAUSA
# 30                               COBERTURA
# 31                                  ESTADO
# 32                           OBSERVACION 1
# 33                           OBSERVACION 2
# 34                                   NOTAS
# 35                                 FACTURA
# 36                               INSPECTOR
# 37                               AJUSTADOR
# 38            NÚMERO DE CONTACTO ASEGURADO
# 39                           CO-EXISTENCIA
# 40                                  BIENES
# 41                                  HECHOS
# 42                                 CREDITO
# 43                          VIGENCIA DESDE
# 44                          VIGENCIA HASTA
# 45                          RAZON OBJECIÓN
# 46                        ENTIDAD BANCARIA
# 47                         CUENTA BANCARIA
# 48                           FORMA DE PAGO
# 49                         RECONSIDERACIÓN
# 50                      FECHA DE RESPUESTA

# %%
#Dado que no están organizadas simetricamente, y basado en el análisis visual, 
#se van a eliminar, de la columna 2020, las columnas que corresponden a los indices 0 y 51

df_w_2020.drop([df_w_2020.columns[50]], axis=1, inplace=True)
df_w_2019.drop([df_w_2019.columns[0]],axis=1,inplace = True)

# %%
#Genero un dataframe que me permita comparar visualmente si las columnas están organizadas de manera simetrica.
columns_2019 = pd.DataFrame(df_w_2019.columns)
columns_2020 = pd.DataFrame(df_w_2020.columns)
columns_2020['2019'] = columns_2019[0]
columns_2020
# Out:
#                                          0  \
# 0                                     ITEM
# 1                      CANTIDAD DE POLIZAS
# 2                                No POLIZA
# 3                                No ZONIC
# 4                        CIUDAD OCURRENCIA
# 5                             DEPARTAMENTO
# 6                                DIRECCION
# 7                                ASEGURADO
# 8                     CEDULA DE CIUDADANIA
# 9                                 PRODUCTO
# 10                              CATEGORIA
# 11                               SINIESTRO
# 12                      FECHA DE SINIESTRO
# 13      FECHA DE CONFIRMACIÓN DE SINIESTRO
# 14                    FECHA AVISO INGETECH
# 15  FECHA DE APROBACIÓN DE OBJECIÓN Y PAGO
# 16                     FECHA DE DEFINICIÓN
# 17      FECHA DE FORMALIZACIÓN DEL RECLAMO
# 18                                SEMÁFORO
# 19                                    MES
# 20                     FECHA DE INSPECCION
# 21             FECHA ENTREGA INFORME FINAL
# 22               FECHA ENVÍO INFORME FINAL
# 23                            RESPONSABLE
# 24                           VALOR RECLAMO
# 25                           VALOR RESERVA
# 26                      VALOR A INDEMNIZAR
# 27                              HONORARIOS
# 28                                   CAUSA
# 29                               COBERTURA
# 30                                  ESTADO
# 31                           OBSERVACION 1
# 32                           OBSERVACION 2
# 33                                   NOTAS
# 34                                 FACTURA
# 35                               INSPECTOR
# 36                               AJUSTADOR
# 37                      NUMERO DE TELEFONO
# 38                           CO-EXISTENCIA
# 39                                  BIENES
# 40                                  HECHOS
# 41                                 CREDITO
# 42                          VIGENCIA DESDE
# 43                          VIGENCIA HASTA
# 44                          RAZON OBJECIÓN
# 45                        ENTIDAD BANCARIA
# 46                         CUENTA BANCARIA
# 47                           FORMA DE PAGO
# 48                         RECONSIDERACIÓN
# 49                      FECHA DE RESPUESTA
#
#                                       2019
# 0                                     ITEM
# 1                      CANTIDAD DE POLIZAS
# 2                                No POLIZA
# 3                                 No ZONIC
# 4                        CIUDAD OCURRENCIA
# 5                             DEPARTAMENTO
# 6                                DIRECCION
# 7                                ASEGURADO
# 8                             CC ASEGURADO
# 9                                 PRODUCTO
# 10                              CATEGORIA
# 11                               SINIESTRO
# 12                      FECHA DE SINIESTRO
# 13      FECHA DE CONFIRMACIÓN DE SINIESTRO
# 14                    FECHA AVISO INGETECH
# 15  FECHA DE APROBACIÓN DE OBJECIÓN Y PAGO
# 16                     FECHA DE DEFINICIÓN
# 17      FECHA DE FORMALIZACIÓN DEL RECLAMO
# 18                                SEMÁFORO
# 19                                    MES
# 20                     FECHA DE INSPECCION
# 21             FECHA ENTREGA INFORME FINAL
# 22               FECHA ENVÍO INFORME FINAL
# 23                            RESPONSABLE
# 24                           VALOR RECLAMO
# 25              VALOR RESERVA (PAGO TOTAL)
# 26                      VALOR A INDEMNIZAR
# 27                              HONORARIOS
# 28                                   CAUSA
# 29                               COBERTURA
# 30                                  ESTADO
# 31                           OBSERVACION 1
# 32                           OBSERVACION 2
# 33                                   NOTAS
# 34                                 FACTURA
# 35                               INSPECTOR
# 36                               AJUSTADOR
# 37            NÚMERO DE CONTACTO ASEGURADO
# 38                           CO-EXISTENCIA
# 39                                  BIENES
# 40                                  HECHOS
# 41                                 CREDITO
# 42                          VIGENCIA DESDE
# 43                          VIGENCIA HASTA
# 44                          RAZON OBJECIÓN
# 45                        ENTIDAD BANCARIA
# 46                         CUENTA BANCARIA
# 47                           FORMA DE PAGO
# 48                         RECONSIDERACIÓN
# 49                      FECHA DE RESPUESTA

# %% [markdown]
# #### OBJETIVO 1 - CUMPLIDO
# Aunque los nombres de columnas no son los mismos, los respectivos dataframes están organizados de manera simetrica.
# En este punto empiezo a realizar una revisión manual, entre los campos de la base de datos de la aplicación, y los features
# ya ordenados en este notebook, de tal manera que se pueda crear un diccionario con base en la posición de las columnas
# en el dataframe. Como resultado de esta revisión se obtuvieron los siguientes resultados:
#
# a. No se encuentra coincidencia de campo en base de datos original para fecha_confirmacion_siniestro.
# b. El campo número de contacto se mapea como telefono_asegurado.
# c. El campo hecho, se mapea como descripcion_siniestro
# d. No existe campo asociado a razón objeción.
# e. No existe campo asociado con reconsideración.
# f. No existe campo asociado con fecha de respuesta.

# %%
#Importo el mapeo de features vs nombres de los campos que realice previamente, de tal manera, que pueda
#crear un diccionario con el cual poder renombrar las columnas de los archivos de excel que se están limpiando.

#importo el archivo csv que contiene el diccionario, creo el dataframe y lo llamo df_columnas
df_columnas = pd.read_csv('diccionario_columnas_chubb.csv')

# %%
#reordenar el dataframe df_columnas, por la columna posicion_bd_originals.
df_columnas.sort_values('posicion_bd_originales', inplace=True)

#descarto los valores nan, de la columna posicion_bd_originales, puesto que hubieron columnas en la base de datos, que
#no se mapearon contra los features de los archivos que son objeto de esta limpieza.

mascara = df_columnas.posicion_bd_originales.notna()
df_columnas = df_columnas[mascara]

#Establezco la columna 'posicion_bd_originals' como el index en el dataframe, de tal manera que me facilite unir
#este dataframe, con el de columns_2020
df_columnas.set_index('posicion_bd_originales',inplace=True)
df_columnas
# Out:
#                                        nombre_campo       tipo_dato
# posicion_bd_originales
# 0.0                                         Item_no         float64
# 1.0                                cantidad_polizas         float64
# 2.0                                       no_poliza          object
# 3.0                                    numero_zonic          object
# 4.0                                ciudad_asegurado          object
# 5.0                          departamento_asegurado          object
# 6.0                             direccion_asegurado          object
# 7.0                                nombre_asegurado          object
# 8.0                                cedula_asegurado          object
# 9.0                                 producto_poliza          object
# 10.0                          categoria_reclamacion          object
# 11.0                                      siniestro          object
# 12.0                                fecha_siniestro  datetime64[ns]
# 14.0                                    fecha_aviso  datetime64[ns]
# 15.0                          fecha_aprobacion_pago  datetime64[ns]
# 16.0                               fecha_definicion  datetime64[ns]
# 17.0                           fecha_aviso_ingetech  datetime64[ns]
# 19.0                                            mes          object
# 20.0                               fecha_inspeccion  datetime64[ns]
# 21.0                    fecha_entrega_informe_final  datetime64[ns]
# 22.0                            fecha_informe_final  datetime64[ns]
# 23.0                                    responsable          object
# 24.0                              valor_reclamacion           int32
# 25.0                                        reserva         float64
# 27.0                                     honorarios         float64
# 28.0                                          causa          object
# 29.0                                      cobertura          object
# 30.0                                         estado          object
# 31.0                                  observacion_1          object
# 32.0                                  observacion_2          object
# 33.0                                          notas          object
# 34.0                                        factura          object
# 35.0                                      inspector          object
# 36.0                                      ajustador          object
# 37.0                             telefono_asegurado          object
# 38.0                                   coexistencia            bool
# 39.0                                         bienes          object
# 40.0                          descripcion_siniestro          object
# 41.0                                 credito_poliza          object
# 42.0                                 vigencia_desde  datetime64[ns]
# 43.0                                 vigencia_hasta  datetime64[ns]
# 45.0                                          banco          object
# 46.0                            numero_cuenta_banco          object
# 47.0                                     forma_pago          object

# %%
#Creo un nuevo dataframe con el cual puedo establecer el nombre de las columnas definitivas.
df_columnas_definitivas = columns_2020.join(df_columnas, lsuffix='_caller', rsuffix='_other')
df_columnas_definitivas
# Out:
#                                          0  \
# 0                                     ITEM
# 1                      CANTIDAD DE POLIZAS
# 2                                No POLIZA
# 3                                No ZONIC
# 4                        CIUDAD OCURRENCIA
# 5                             DEPARTAMENTO
# 6                                DIRECCION
# 7                                ASEGURADO
# 8                     CEDULA DE CIUDADANIA
# 9                                 PRODUCTO
# 10                              CATEGORIA
# 11                               SINIESTRO
# 12                      FECHA DE SINIESTRO
# 13      FECHA DE CONFIRMACIÓN DE SINIESTRO
# 14                    FECHA AVISO INGETECH
# 15  FECHA DE APROBACIÓN DE OBJECIÓN Y PAGO
# 16                     FECHA DE DEFINICIÓN
# 17      FECHA DE FORMALIZACIÓN DEL RECLAMO
# 18                                SEMÁFORO
# 19                                    MES
# 20                     FECHA DE INSPECCION
# 21             FECHA ENTREGA INFORME FINAL
# 22               FECHA ENVÍO INFORME FINAL
# 23                            RESPONSABLE
# 24                           VALOR RECLAMO
# 25                           VALOR RESERVA
# 26                      VALOR A INDEMNIZAR
# 27                              HONORARIOS
# 28                                   CAUSA
# 29                               COBERTURA
# 30                                  ESTADO
# 31                           OBSERVACION 1
# 32                           OBSERVACION 2
# 33                                   NOTAS
# 34                                 FACTURA
# 35                               INSPECTOR
# 36                               AJUSTADOR
# 37                      NUMERO DE TELEFONO
# 38                           CO-EXISTENCIA
# 39                                  BIENES
# 40                                  HECHOS
# 41                                 CREDITO
# 42                          VIGENCIA DESDE
# 43                          VIGENCIA HASTA
# 44                          RAZON OBJECIÓN
# 45                        ENTIDAD BANCARIA
# 46                         CUENTA BANCARIA
# 47                           FORMA DE PAGO
# 48                         RECONSIDERACIÓN
# 49                      FECHA DE RESPUESTA
#
#                                       2019                 nombre_campo  \
# 0                                     ITEM                      Item_no
# 1                      CANTIDAD DE POLIZAS             cantidad_polizas
# 2                                No POLIZA                    no_poliza
# 3                                 No ZONIC                 numero_zonic
# 4                        CIUDAD OCURRENCIA             ciudad_asegurado
# 5                             DEPARTAMENTO       departamento_asegurado
# 6                                DIRECCION          direccion_asegurado
# 7                                ASEGURADO             nombre_asegurado
# 8                             CC ASEGURADO             cedula_asegurado
# 9                                 PRODUCTO              producto_poliza
# 10                              CATEGORIA         categoria_reclamacion
# 11                               SINIESTRO                    siniestro
# 12                      FECHA DE SINIESTRO              fecha_siniestro
# 13      FECHA DE CONFIRMACIÓN DE SINIESTRO                          NaN
# 14                    FECHA AVISO INGETECH                  fecha_aviso
# 15  FECHA DE APROBACIÓN DE OBJECIÓN Y PAGO        fecha_aprobacion_pago
# 16                     FECHA DE DEFINICIÓN             fecha_definicion
# 17      FECHA DE FORMALIZACIÓN DEL RECLAMO         fecha_aviso_ingetech
# 18                                SEMÁFORO                          NaN
# 19                                    MES                           mes
# 20                     FECHA DE INSPECCION             fecha_inspeccion
# 21             FECHA ENTREGA INFORME FINAL  fecha_entrega_informe_final
# 22               FECHA ENVÍO INFORME FINAL          fecha_informe_final
# 23                            RESPONSABLE                   responsable
# 24                           VALOR RECLAMO            valor_reclamacion
# 25              VALOR RESERVA (PAGO TOTAL)                      reserva
# 26                      VALOR A INDEMNIZAR                          NaN
# 27                              HONORARIOS                   honorarios
# 28                                   CAUSA                        causa
# 29                               COBERTURA                    cobertura
# 30                                  ESTADO                       estado
# 31                           OBSERVACION 1                observacion_1
# 32                           OBSERVACION 2                observacion_2
# 33                                   NOTAS                        notas
# 34                                 FACTURA                      factura
# 35                               INSPECTOR                    inspector
# 36                               AJUSTADOR                    ajustador
# 37            NÚMERO DE CONTACTO ASEGURADO           telefono_asegurado
# 38                           CO-EXISTENCIA                 coexistencia
# 39                                  BIENES                       bienes
# 40                                  HECHOS        descripcion_siniestro
# 41                                 CREDITO               credito_poliza
# 42                          VIGENCIA DESDE               vigencia_desde
# 43                          VIGENCIA HASTA               vigencia_hasta
# 44                          RAZON OBJECIÓN                          NaN
# 45                        ENTIDAD BANCARIA                        banco
# 46                         CUENTA BANCARIA          numero_cuenta_banco
# 47                           FORMA DE PAGO                   forma_pago
# 48                         RECONSIDERACIÓN                          NaN
# 49                      FECHA DE RESPUESTA                          NaN
#
#          tipo_dato
# 0          float64
# 1          float64
# 2           object
# 3           object
# 4           object
# 5           object
# 6           object
# 7           object
# 8           object
# 9           object
# 10          object
# 11          object
# 12  datetime64[ns]
# 13             NaN
# 14  datetime64[ns]
# 15  datetime64[ns]
# 16  datetime64[ns]
# 17  datetime64[ns]
# 18             NaN
# 19          object
# 20  datetime64[ns]
# 21  datetime64[ns]
# 22  datetime64[ns]
# 23          object
# 24           int32
# 25         float64
# 26             NaN
# 27         float64
# 28          object
# 29          object
# 30          object
# 31          object
# 32          object
# 33          object
# 34          object
# 35          object
# 36          object
# 37          object
# 38            bool
# 39          object
# 40          object
# 41          object
# 42  datetime64[ns]
# 43  datetime64[ns]
# 44             NaN
# 45          object
# 46          object
# 47          object
# 48             NaN
# 49             NaN

# %%
#identifico las columnas que voy a descartar al realizar la migración
mascara_columnas_a_descartar = df_columnas_definitivas['nombre_campo'].isna()
columnas_descartar = list(df_columnas_definitivas[mascara_columnas_a_descartar].index)

# %%
#Eliminamos las columnas en los dataset originales, que no se mapearon.
df_w_2019.drop(df_w_2019.iloc[:,columnas_descartar], inplace = True, axis = 1)
df_w_2020.drop(df_w_2020.iloc[:,columnas_descartar], inplace = True, axis = 1)

# %%
#Revisamos el número de columnas resultante. Evidenemnete se eliminaron las columnas que se indicaron, pasando de 50 a 44.
print(df_w_2019.shape)
print(df_w_2020.shape)
# Out:
# (1208, 44)
# (501, 44)

# %%
#Ahora reemplazo los nombres de las columnas actuales, por los nombres de los campos en la base de datos a la cuál 
#se va a migrar. Teniendo en cuenta que en el año 2019 y 2020, los nombres varían es necesario crear dos diccionarios.

#Filtro los valores que no son nan, y actualizo el dataframe df_columnas_definitivas con ese resultado.
mascara_diccionario = df_columnas_definitivas.notna()
df_columnas_definitivas = df_columnas_definitivas[mascara_diccionario]

df_columnas_definitivas
# Out:
#                                          0  \
# 0                                     ITEM
# 1                      CANTIDAD DE POLIZAS
# 2                                No POLIZA
# 3                                No ZONIC
# 4                        CIUDAD OCURRENCIA
# 5                             DEPARTAMENTO
# 6                                DIRECCION
# 7                                ASEGURADO
# 8                     CEDULA DE CIUDADANIA
# 9                                 PRODUCTO
# 10                              CATEGORIA
# 11                               SINIESTRO
# 12                      FECHA DE SINIESTRO
# 13      FECHA DE CONFIRMACIÓN DE SINIESTRO
# 14                    FECHA AVISO INGETECH
# 15  FECHA DE APROBACIÓN DE OBJECIÓN Y PAGO
# 16                     FECHA DE DEFINICIÓN
# 17      FECHA DE FORMALIZACIÓN DEL RECLAMO
# 18                                SEMÁFORO
# 19                                    MES
# 20                     FECHA DE INSPECCION
# 21             FECHA ENTREGA INFORME FINAL
# 22               FECHA ENVÍO INFORME FINAL
# 23                            RESPONSABLE
# 24                           VALOR RECLAMO
# 25                           VALOR RESERVA
# 26                      VALOR A INDEMNIZAR
# 27                              HONORARIOS
# 28                                   CAUSA
# 29                               COBERTURA
# 30                                  ESTADO
# 31                           OBSERVACION 1
# 32                           OBSERVACION 2
# 33                                   NOTAS
# 34                                 FACTURA
# 35                               INSPECTOR
# 36                               AJUSTADOR
# 37                      NUMERO DE TELEFONO
# 38                           CO-EXISTENCIA
# 39                                  BIENES
# 40                                  HECHOS
# 41                                 CREDITO
# 42                          VIGENCIA DESDE
# 43                          VIGENCIA HASTA
# 44                          RAZON OBJECIÓN
# 45                        ENTIDAD BANCARIA
# 46                         CUENTA BANCARIA
# 47                           FORMA DE PAGO
# 48                         RECONSIDERACIÓN
# 49                      FECHA DE RESPUESTA
#
#                                       2019                 nombre_campo  \
# 0                                     ITEM                      Item_no
# 1                      CANTIDAD DE POLIZAS             cantidad_polizas
# 2                                No POLIZA                    no_poliza
# 3                                 No ZONIC                 numero_zonic
# 4                        CIUDAD OCURRENCIA             ciudad_asegurado
# 5                             DEPARTAMENTO       departamento_asegurado
# 6                                DIRECCION          direccion_asegurado
# 7                                ASEGURADO             nombre_asegurado
# 8                             CC ASEGURADO             cedula_asegurado
# 9                                 PRODUCTO              producto_poliza
# 10                              CATEGORIA         categoria_reclamacion
# 11                               SINIESTRO                    siniestro
# 12                      FECHA DE SINIESTRO              fecha_siniestro
# 13      FECHA DE CONFIRMACIÓN DE SINIESTRO                          NaN
# 14                    FECHA AVISO INGETECH                  fecha_aviso
# 15  FECHA DE APROBACIÓN DE OBJECIÓN Y PAGO        fecha_aprobacion_pago
# 16                     FECHA DE DEFINICIÓN             fecha_definicion
# 17      FECHA DE FORMALIZACIÓN DEL RECLAMO         fecha_aviso_ingetech
# 18                                SEMÁFORO                          NaN
# 19                                    MES                           mes
# 20                     FECHA DE INSPECCION             fecha_inspeccion
# 21             FECHA ENTREGA INFORME FINAL  fecha_entrega_informe_final
# 22               FECHA ENVÍO INFORME FINAL          fecha_informe_final
# 23                            RESPONSABLE                   responsable
# 24                           VALOR RECLAMO            valor_reclamacion
# 25              VALOR RESERVA (PAGO TOTAL)                      reserva
# 26                      VALOR A INDEMNIZAR                          NaN
# 27                              HONORARIOS                   honorarios
# 28                                   CAUSA                        causa
# 29                               COBERTURA                    cobertura
# 30                                  ESTADO                       estado
# 31                           OBSERVACION 1                observacion_1
# 32                           OBSERVACION 2                observacion_2
# 33                                   NOTAS                        notas
# 34                                 FACTURA                      factura
# 35                               INSPECTOR                    inspector
# 36                               AJUSTADOR                    ajustador
# 37            NÚMERO DE CONTACTO ASEGURADO           telefono_asegurado
# 38                           CO-EXISTENCIA                 coexistencia
# 39                                  BIENES                       bienes
# 40                                  HECHOS        descripcion_siniestro
# 41                                 CREDITO               credito_poliza
# 42                          VIGENCIA DESDE               vigencia_desde
# 43                          VIGENCIA HASTA               vigencia_hasta
# 44                          RAZON OBJECIÓN                          NaN
# 45                        ENTIDAD BANCARIA                        banco
# 46                         CUENTA BANCARIA          numero_cuenta_banco
# 47                           FORMA DE PAGO                   forma_pago
# 48                         RECONSIDERACIÓN                          NaN
# 49                      FECHA DE RESPUESTA                          NaN
#
#          tipo_dato
# 0          float64
# 1          float64
# 2           object
# 3           object
# 4           object
# 5           object
# 6           object
# 7           object
# 8           object
# 9           object
# 10          object
# 11          object
# 12  datetime64[ns]
# 13             NaN
# 14  datetime64[ns]
# 15  datetime64[ns]
# 16  datetime64[ns]
# 17  datetime64[ns]
# 18             NaN
# 19          object
# 20  datetime64[ns]
# 21  datetime64[ns]
# 22  datetime64[ns]
# 23          object
# 24           int32
# 25         float64
# 26             NaN
# 27         float64
# 28          object
# 29          object
# 30          object
# 31          object
# 32          object
# 33          object
# 34          object
# 35          object
# 36          object
# 37          object
# 38            bool
# 39          object
# 40          object
# 41          object
# 42  datetime64[ns]
# 43  datetime64[ns]
# 44             NaN
# 45          object
# 46          object
# 47          object
# 48             NaN
# 49             NaN

# %%
#creo los diccionarios para cada año, teniendo en cuenta que la información de cada año está en datasets diferentes
diccionario_2019 = dict(zip(df_columnas_definitivas['2019'], df_columnas_definitivas['nombre_campo']))
diccionario_2020 = dict(zip(df_columnas_definitivas[0], df_columnas_definitivas['nombre_campo']))

# %%
#Verifico que los diccionarios se hayan creado
diccionario_2019, diccionario_2020
# Out:
# ({'ITEM': 'Item_no',
#   'CANTIDAD DE POLIZAS': 'cantidad_polizas',
#   'No POLIZA': 'no_poliza',
#   'No ZONIC': 'numero_zonic',
#   'CIUDAD OCURRENCIA': 'ciudad_asegurado',
#   'DEPARTAMENTO': 'departamento_asegurado',
#   'DIRECCION': 'direccion_asegurado',
#   'ASEGURADO': 'nombre_asegurado',
#   'CC ASEGURADO': 'cedula_asegurado',
#   'PRODUCTO': 'producto_poliza',
#   'CATEGORIA ': 'categoria_reclamacion',
#   'SINIESTRO': 'siniestro',
#   'FECHA DE SINIESTRO': 'fecha_siniestro',
#   'FECHA DE CONFIRMACIÓN DE SINIESTRO': nan,
#   'FECHA AVISO INGETECH': 'fecha_aviso',
#   'FECHA DE APROBACIÓN DE OBJECIÓN Y PAGO': 'fecha_aprobacion_pago',
#   'FECHA DE DEFINICIÓN': 'fecha_definicion',
#   'FECHA DE FORMALIZACIÓN DEL RECLAMO': 'fecha_aviso_ingetech',
#   'SEMÁFORO': nan,
#   'MES ': 'mes',
#   'FECHA DE INSPECCION': 'fecha_inspeccion',
#   'FECHA ENTREGA INFORME FINAL': 'fecha_entrega_informe_final',
#   'FECHA ENVÍO INFORME FINAL': 'fecha_informe_final',
#   'RESPONSABLE ': 'responsable',
#   'VALOR RECLAMO': 'valor_reclamacion',
#   'VALOR RESERVA (PAGO TOTAL)': 'reserva',
#   'VALOR A INDEMNIZAR': nan,
#   'HONORARIOS': 'honorarios',
#   'CAUSA': 'causa',
#   'COBERTURA': 'cobertura',
#   'ESTADO': 'estado',
#   'OBSERVACION 1': 'observacion_1',
#   'OBSERVACION 2': 'observacion_2',
#   'NOTAS': 'notas',
#   'FACTURA': 'factura',
#   'INSPECTOR': 'inspector',
#   'AJUSTADOR': 'ajustador',
#   'NÚMERO DE CONTACTO ASEGURADO': 'telefono_asegurado',
#   'CO-EXISTENCIA': 'coexistencia',
#   'BIENES': 'bienes',
#   'HECHOS': 'descripcion_siniestro',
#   'CREDITO': 'credito_poliza',
#   'VIGENCIA DESDE': 'vigencia_desde',
#   'VIGENCIA HASTA': 'vigencia_hasta',
#   'RAZON OBJECIÓN': nan,
#   'ENTIDAD BANCARIA': 'banco',
#   'CUENTA BANCARIA': 'numero_cuenta_banco',
#   'FORMA DE PAGO': 'forma_pago',
#   'RECONSIDERACIÓN': nan,
#   'FECHA DE RESPUESTA': nan},
#  {'ITEM': 'Item_no',
#   'CANTIDAD DE POLIZAS': 'cantidad_polizas',
#   'No POLIZA': 'no_poliza',
#   'No ZONIC ': 'numero_zonic',
#   'CIUDAD OCURRENCIA': 'ciudad_asegurado',
#   'DEPARTAMENTO': 'departamento_asegurado',
#   'DIRECCION': 'direccion_asegurado',
#   'ASEGURADO': 'nombre_asegurado',
#   'CEDULA DE CIUDADANIA': 'cedula_asegurado',
#   'PRODUCTO': 'producto_poliza',
#   'CATEGORIA ': 'categoria_reclamacion',
#   'SINIESTRO': 'siniestro',
#   'FECHA DE SINIESTRO': 'fecha_siniestro',
#   'FECHA DE CONFIRMACIÓN DE SINIESTRO': nan,
#   'FECHA AVISO INGETECH': 'fecha_aviso',
#   'FECHA DE APROBACIÓN DE OBJECIÓN Y PAGO': 'fecha_aprobacion_pago',
#   'FECHA DE DEFINICIÓN': 'fecha_definicion',
#   'FECHA DE FORMALIZACIÓN DEL RECLAMO': 'fecha_aviso_ingetech',
#   'SEMÁFORO': nan,
#   'MES ': 'mes',
#   'FECHA DE INSPECCION': 'fecha_inspeccion',
#   'FECHA ENTREGA INFORME FINAL': 'fecha_entrega_informe_final',
#   'FECHA ENVÍO INFORME FINAL': 'fecha_informe_final',
#   'RESPONSABLE ': 'responsable',
#   'VALOR RECLAMO': 'valor_reclamacion',
#   'VALOR RESERVA': 'reserva',
#   'VALOR A INDEMNIZAR': nan,
#   'HONORARIOS': 'honorarios',
#   'CAUSA': 'causa',
#   'COBERTURA': 'cobertura',
#   'ESTADO': 'estado',
#   'OBSERVACION 1': 'observacion_1',
#   'OBSERVACION 2': 'observacion_2',
#   'NOTAS': 'notas',
#   'FACTURA': 'factura',
#   'INSPECTOR': 'inspector',
#   'AJUSTADOR': 'ajustador',
#   'NUMERO DE TELEFONO': 'telefono_asegurado',
#   'CO-EXISTENCIA': 'coexistencia',
#   'BIENES': 'bienes',
#   'HECHOS': 'descripcion_siniestro',
#   'CREDITO': 'credito_poliza',
#   'VIGENCIA DESDE': 'vigencia_desde',
#   'VIGENCIA HASTA': 'vigencia_hasta',
#   'RAZON OBJECIÓN': nan,
#   'ENTIDAD BANCARIA': 'banco',
#   'CUENTA BANCARIA': 'numero_cuenta_banco',
#   'FORMA DE PAGO': 'forma_pago',
#   'RECONSIDERACIÓN': nan,
#   'FECHA DE RESPUESTA': nan})

# %%
#Renombro las columnas para cada uno de los datasets originales
df_w_2019.rename(columns=diccionario_2019, inplace=True)
df_w_2020.rename(columns=diccionario_2020, inplace=True)

# %%
#Verifico que el cambio de nombres de columnas se haya realizado.
df_w_2019.columns, df_w_2020.columns
# Out:
# (Index(['Item_no', 'cantidad_polizas', 'no_poliza', 'numero_zonic',
#         'ciudad_asegurado', 'departamento_asegurado', 'direccion_asegurado',
#         'nombre_asegurado', 'cedula_asegurado', 'producto_poliza',
#         'categoria_reclamacion', 'siniestro', 'fecha_siniestro', 'fecha_aviso',
#         'fecha_aprobacion_pago', 'fecha_definicion', 'fecha_aviso_ingetech',
#         'mes', 'fecha_inspeccion', 'fecha_entrega_informe_final',
#         'fecha_informe_final', 'responsable', 'valor_reclamacion', 'reserva',
#         'honorarios', 'causa', 'cobertura', 'estado', 'observacion_1',
#         'observacion_2', 'notas', 'factura', 'inspector', 'ajustador',
#         'telefono_asegurado', 'coexistencia', 'bienes', 'descripcion_siniestro',
#         'credito_poliza', 'vigencia_desde', 'vigencia_hasta', 'banco',
#         'numero_cuenta_banco', 'forma_pago'],
#        dtype='object'),
#  Index(['Item_no', 'cantidad_polizas', 'no_poliza', 'numero_zonic',
#         'ciudad_asegurado', 'departamento_asegurado', 'direccion_asegurado',
#         'nombre_asegurado', 'cedula_asegurado', 'producto_poliza',
#         'categoria_reclamacion', 'siniestro', 'fecha_siniestro', 'fecha_aviso',
#         'fecha_aprobacion_pago', 'fecha_definicion', 'fecha_aviso_ingetech',
#         'mes', 'fecha_inspeccion', 'fecha_entrega_informe_final',
#         'fecha_informe_final', 'responsable', 'valor_reclamacion', 'reserva',
#         'honorarios', 'causa', 'cobertura', 'estado', 'observacion_1',
#         'observacion_2', 'notas', 'factura', 'inspector', 'ajustador',
#         'telefono_asegurado', 'coexistencia', 'bienes', 'descripcion_siniestro',
#         'credito_poliza', 'vigencia_desde', 'vigencia_hasta', 'banco',
#         'numero_cuenta_banco', 'forma_pago'],
#        dtype='object'))

# %% [markdown]
# #### Objetivo 2, cumplido.
#
# ## Parte 2 - Revisión de tipos de datos de los features para garantizar que coincidan con la base de datos de la aplicación a la cuál se van a migrar.
#
# Objetivos:
#
# 1. Crear un único dataframe y garantizar que los valores faltantes que tenga correspondan a la dinámica del negocio, y no
# a errores en la limpieza de los datos.
# 2. Garantizar que los tipos de datos de los campos del nuevo_dataframe sean coincidentes con los tipos de datos de los campos de la aplicación.

# %%
df_w_2019['year'] = 2019
df_w_2020['year'] = 2020

# %%
df_w_2019['categoria_reclamacion'].value_counts()
# Out:
# NORMAL    509
# MASIVO    507
# ÚNICO     192
# Name: categoria_reclamacion, dtype: int64

# %%
df_w_2019.shape, df_w_2020.shape
# Out:
# ((1208, 45), (501, 45))

# %%
#Creo un dataframe df_migrar que contiene la información de los dos años, y los cuales, tienen los nombres de columna actualizados
df_migrar = pd.concat([df_w_2019, df_w_2020])

# %%
#Verifico la forma del nuevo dataframe, y si el número de filas se adicionaron correctamente.
print(df_migrar.shape, df_w_2019.shape, df_w_2020.shape)
# Out:
# (1709, 45) (1208, 45) (501, 45)

# %%
df_migrar['categoria_reclamacion'].value_counts()
# Out:
# NORMAL    584
# MASIVO    507
# ÚNICO     192
# Name: categoria_reclamacion, dtype: int64

# %%
#Reviso cuántos valores faltantes hay por cada feature.
df_migrar.isna().sum()
# Out:
# Item_no                          0
# cantidad_polizas               431
# no_poliza                      427
# numero_zonic                   432
# ciudad_asegurado               425
# departamento_asegurado         426
# direccion_asegurado            427
# nombre_asegurado               425
# cedula_asegurado               425
# producto_poliza                426
# categoria_reclamacion          426
# siniestro                      431
# fecha_siniestro                426
# fecha_aviso                    426
# fecha_aprobacion_pago          467
# fecha_definicion               483
# fecha_aviso_ingetech           452
# mes                            426
# fecha_inspeccion               692
# fecha_entrega_informe_final    457
# fecha_informe_final            981
# responsable                    426
# valor_reclamacion              427
# reserva                        447
# honorarios                     429
# causa                          428
# cobertura                      428
# estado                         426
# observacion_1                  427
# observacion_2                  427
# notas                          426
# factura                        525
# inspector                      427
# ajustador                      426
# telefono_asegurado             498
# coexistencia                   426
# bienes                         431
# descripcion_siniestro          430
# credito_poliza                 427
# vigencia_desde                 427
# vigencia_hasta                 427
# banco                          763
# numero_cuenta_banco            763
# forma_pago                     813
# year                             0
# dtype: int64

# %% [markdown]
# #### Objetivo 1, cumplido

# %%
#Reviso los tipos de datos que tiene cada columna, y verificar si hay compatibilidad con el tipo de datos en la
#base de datos de la aplicación. 

#Generos un dataframe con los tipos de datos de cada columna en el dataset actual.

df_migrar_tipos_datos = pd.DataFrame(df_migrar.dtypes)

#Agrego una columna adicional, con la cual visualizar el tipo de dato que se requiere en la base de datos a migrar.

diccionario_tipo_datos = dict(zip(df_columnas_definitivas['nombre_campo'], df_columnas_definitivas['tipo_dato']))
df_migrar_tipos_datos['tipo_dato'] = df_migrar_tipos_datos.index.map(diccionario_tipo_datos)

#identifico los features que no comparten el mismo tipo de datos para examinarlos posteriormente.

mask = df_migrar_tipos_datos[0] != df_migrar_tipos_datos['tipo_dato']
df_migrar_tipos_datos[mask]
# Out:
#                          0       tipo_dato
# Item_no              int64         float64
# no_poliza          float64          object
# cedula_asegurado   float64          object
# valor_reclamacion   object           int32
# coexistencia        object            bool
# vigencia_desde      object  datetime64[ns]
# vigencia_hasta      object  datetime64[ns]
# year                 int64             NaN

# %% [markdown]
# Se identifican 7 features en los cuales los tipos de datos <b>no coinciden.</b>

# %%
#Convierto de integer a string (object), el campo no_poliza
print(df_migrar['no_poliza'])
df_migrar['no_poliza'] = df_migrar['no_poliza'].apply(str)
df_migrar['cedula_asegurado'] = df_migrar['cedula_asegurado'].apply(str)
# Out:
# 0      2669.0
# 1      2669.0
# 2      2669.0
# 3      2669.0
# 4      2669.0
#         ...
# 496       NaN
# 497       NaN
# 498       NaN
# 499       NaN
# 500       NaN
# Name: no_poliza, Length: 1709, dtype: float64

# %%
#Convierto de object a datetime, los features que fueron mal tipificados inicialmente.

df_migrar['fecha_inspeccion'] = pd.to_datetime(df_migrar.fecha_inspeccion.fillna(pd.NaT), errors='coerce')
df_migrar['vigencia_desde'] = pd.to_datetime(df_migrar.vigencia_desde.fillna(pd.NaT), errors='coerce')
df_migrar['vigencia_hasta'] = pd.to_datetime(df_migrar.vigencia_hasta.fillna(pd.NaT), errors='coerce')

# %%
#Convierto de Object (String) a integer

#Reviso cuales son los valores que hacen que el campo no sea tomado como "Integer". 
df_migrar['valor_reclamacion'].unique()
# Out:
# array(['NO REPORTA', 'NO REPORTA ', 4668980, 926030, 3609900, 1780000,
#        614000, 900000, 2000000, 400000, 1820947, 1070000, 1150000, 959500,
#        5565500, 1332000, 4000000, 1776000, 5569400, 5896000, 5770000,
#        20633000, 35000000, 14000000, 5077000, 11067800, 16066900,
#        14933924, 4875000, 6000000, 13499900, 2257500, 20009600, 3000000,
#        15794341, 5946800, 7630000, 18929216, 27268700, 6841000, 6914700,
#        3483998, 26063000, 11873000, 16000000, 4722500, 5000000, 12562500,
#        18000000, 20392000, 18551001, 25117500, 6772000, 16459200,
#        54252100, 11124500, 9301366, 18785000, 21459301, 9090000, 7613000,
#        12572500, 7183000, 10000000, 19137000, 7400000, 5584000, 14355400,
#        2499900, 13338500, 6929000, 5100000, 17348000, 10609550, 14674000,
#        10728000, 7897000, 9305200, 7212200, 6925214, 15174851, 4730000,
#        1440500, 5348200, 9899700, 5547000, 23388700, 3838500, 7254600,
#        10692000, 18577200, 10415000, 15744450, 3268000, 16882000,
#        11569300, 10473479, 5165000, 4500000, 10205000, 5361500, 15325200,
#        11284059, 3963500, 4327255, 1130000, 11472200, 11756500, 15772000,
#        11343900, 7000000, 6695700, 16315000, 15762500, 21100000, 39137000,
#        5671700, 25722200, 4002000, 2887601, 14005651, 3590121, 10502500,
#        15220000, 5319000, 10198898, 15178651, 5702832, 3499900, 850000,
#        3023500, 2410000, 3400500, 2645379, 1399500, 442000, 1405000,
#        679000, 9471200, 10957400, 15869000, 17067200, 22000000, 2664100,
#        11556381, 14617500, 17679500, 7877800, 7517204, 11121000, 3733000,
#        7565000, 1540000, 7456250, 3023000, 1297200, 10700000, 9108149,
#        11616500, 9500000, 5181800, 11600000, 4720800, 72269300, 5430800,
#        18291000, 3899900, 59199196, 10977500, 5114800, 0, 2069118,
#        8626250, 22891964, 4101000, 32192755, 3600000, 7052000, 4060000,
#        16605200, 10072497, 2020000, 7770500, 13442400, 38436400, 10511000,
#        3975400, 4970500, 5380500, 2500405, 3165240, 4171800, 2164400,
#        10100000, 5391000, 2900000, 12146708, 8000000, 9420000, 8024000,
#        6967728, 4740999, 5600000, 6800000, 4546000, 4450000, 5288000,
#        5925600, 19625222, 7024500, 13647000, 2984400, 920000, 7965400,
#        9761000, 2100000, 10630000, 10227900, 45000000, 10070850, 13634150,
#        25000000, 13966000, 15000000, 10176000, 2311401, 9940000, 1238941,
#        25061600, 1503800, 23000000, 2251000, 5767000, 26000000, 7906300,
#        7141000, 2187000, 6477200, 2338000, 12531000, 2780000, 4029000,
#        12120700, 9253500, 11960000, 11464500, 12000000, 6007000, 12782400,
#        19046200, 19619100, 15007200, 15130000, 3616000, 4291754, 1648400,
#        14205000, 12146000, 14540000, 5409450, 3800000, 27298045, 12285000,
#        3426100, 3034971, 3581400, 4339000, 2500000, 3506400, 4854700,
#        3170000, 3531000, 2494200, 2800000, 10473000, 5230000, 1800000,
#        5456000, 1941700, 1784200, 6900000, 3298000, 8592000, 24224500,
#        5310300, 3716150, 1030000, 2300000, 1602900, 6092000, 15388000,
#        12315000, 20198000, 7160000, 8091000, 5074000, 2802270, 3559000,
#        925057, 3516000, 8027500, 2889500, 6153000, 16502000, 2523700,
#        9460000, 8335636, 12475200, 1932500, 780000, 9890000, 7037400,
#        6663000, 5560900, 7528700, 6060000, 8252800, 10362000, 8416950,
#        8329000, 23517200, 25836600, 11500000, 6166302, 9000000, 5421000,
#        5590000, 5500000, 5299800, 20700000, 37000000, 15020000, 6100000,
#        5166000, 20648198, 5387476, 15153800, 10840000, 16853000, 7500000,
#        11072530, 6576700, 5200000, 6428000, 5548150, 5364200, 11240600,
#        16428000, 5099000, 9771300, 5029000, 11000000, 10443500, 12057505,
#        41496800, 14834535, 18132000, 10600000, 10603731, 5276000,
#        17020000, 11274000, 7700000, 14158150, 7308759, 8500000, 8935200,
#        6532500, 6293200, 16166000, 9199800, 9100000, 6001000, 10175000,
#        9480000, 14339000, 5154500, 11925000, 90000000, 7820000, 19494500,
#        7830800, 7776000, 6288000, 15475000, 11246300, 9979580, 20648900,
#        9184000, 6400600, 5710000, 18904000, 11492050, 8719000, 8670000,
#        8850500, 9123500, 7155300, 32786000, 4800000, 7136200, 5553000,
#        7114000, 12266500, 12835800, 8335000, 17000000, 12192000, 10893600,
#        32000000, 5893000, 21547000, 15939800, 7800000, 14712500, 5400000,
#        11136392, 6036000, 7100000, 13043520, 6443000, 7564900, 5076000,
#        15870000, 7020755, 10365000, 6260480, 9937800, 6700000, 14221000,
#        10383800, 15230000, 10730000, 10102800, 9246000, 13000000, 9950000,
#        18891600, 10328000, 25620536, 7071000, 7990000, 5638000, 19634000,
#        18706600, 10105000, 98000000, 6905500, 12073500, 46000000, 6243000,
#        11156060, 7461800, 31878000, 28385500, 20716000, 5650000, 10699000,
#        7952000, 4603328, 24129818, 16628000, 7550000, 8917000, 20170000,
#        11404100, 9055000, 5880000, 11522000, 14702950, 12600000, 18986180,
#        32105035, 5140000, 8488400, 10890000, 19922172, 3250000, 4977900,
#        3150000, 4600346, 750000, 3670000, 3500000, 3314000, 1143000,
#        960800, 4612800, 2928000, 350000, 4308300, 3223600, 4900400,
#        4497248, 2014538, 426000, 2375000, 2457400, 3780925, 790000,
#        '\xa0$ 2.240.000\xa0', 4449900, 3219800, 1562200, 1000000, 1355000,
#        739140, 700000, 1866000, 2865000, 600000, 2760000, 1998000,
#        1349900, 3090000, 38000, 1711320, 3111000, 3787400, 1499800,
#        625000, 1277000, 3200000, 1346900, 3990684, 4484000, 3824000,
#        1640000, 3914500, 1590900, 4516250, 2587900, 2890000, 3900000,
#        4748000, 4674000, 4107400, 2519000, 2344000, 1119000, 2954000,
#        2369750, 4669000, 2794600, 1554900, 2207000, 2579400, 791000,
#        1450000, 1635000, 4563200, 460000, 2753500, 2520000, 855020,
#        3796382, 3550000, 3693000, 1804000, 1500000, 5680000, 840000,
#        3308000, 5593500, 3930500, 3747500, 2815245, 4918000, 2486000,
#        3993950, 2399000, 4081000, 3954800, 2583300, 2653600, 2271000,
#        4390000, 4027300, 4935700, 4479500, 552000, 2500100, 4040000,
#        2190300, 4311000, 2035400, 2804000, 1100000, 1579000, 2516000,
#        1598000, 4890000, 1285000, 3230000, 693000, 4392400, 1850000,
#        4359000, 2187750, 3080000, 1429000, 4862602, 1080000, 2254880,
#        1167000, 1839000, 3713200, 3490500, 4014000, 2263262, 2481000,
#        4113934, 1715000, 3236600, 200000, 520000, 2413400, 1014500,
#        1888000, 3710865, 3950640, 3132400, 1376100, 1847100, 3427000,
#        1340000, 4811200, 3846500, 3443000, 2948700, 3859500, 3109701,
#        3039100, 2249200, 24940000.0, 14242000.0, 10200000.0, 6268300.0,
#        7973550.0, 6864000.0, 5279000.0, 19847500.0, 21000000.0,
#        12900000.0, 9207000.0, 7814600.0, 30385500.0, 6280000.0, 5922500.0,
#        6930000.0, 9763000.0, 11033807.0, 12376000.0, 5914000.0,
#        16617500.0, 10799800.0, 10089844.0, 14111150.0, 6690500.0,
#        7660000.0, 13499975.0, 9957000.0, 6043460.0, 8632606.0, 7276314.0,
#        9900000.0, 7172100.0, 22484306.0, 22535744.0, 5759000.0,
#        14984955.0, 16011823.0, 13492300.0, 14680000.0, 19471797.0,
#        10950000.0, 8465000.0, 16923672.0, 6451900.0, 11763400.0,
#        17230000.0, 4516700.0, 3140000.0, 12223454.0, 13236252.0,
#        5017534.0, nan, 8745250.0, 5229000.0, 11643774.0, 9391000.0,
#        5350700.0, 5033800.0, 6382000.0, 6017300.0, 6730000.0, 15266500.0,
#        9789500.0, 5873500.0, 6478000.0, 9338388.0, 9595000.0, 17490000.0,
#        24735000.0], dtype=object)

# %% [markdown]
# Se identifican cuatro valores que <b>NO</b> son tomados como integer.
#
# <b>NO REPORTA </b>- De tipo texto (string)
#
# <b>NO REPORTA </b>- De tipo texto (string)
#
# <b>3.959.00 </b>- Aparentemente un número, pero de tipo texto (String), de igual manera el valor hay que revisarlo manualmente, puesto que queda la duda si es 3959 ó 395900
#
# <b> '\xa0$ 2.240.000\xa0' </b> Aparentemente un número, pero de tipo texto (String)
#
# <b>nan</b>- Posiblemente espacios en blanco u otros caracteres que no son reconocidos como número.

# %%
#Creo un archivo de excel para entregar de tal manera que se pueda hacer una revisión manual.
mask = np.logical_or(df_migrar['valor_reclamacion'] == '3.959.00' , df_migrar['valor_reclamacion'] == '\xa0$ 2.240.000\xa0')
df_migrar[mask].to_excel('revisar_valor_reclamacion.xlsx')

# %%
#convierto a 0 los valores antes mencionados, como forma establecida para imputar.

df_migrar['valor_reclamacion'] = df_migrar['valor_reclamacion'].replace('NO REPORTA',0)
df_migrar['valor_reclamacion'] = df_migrar['valor_reclamacion'].replace('NO REPORTA ',0)
df_migrar['valor_reclamacion'] = df_migrar['valor_reclamacion'].replace('3.959.00',0)
df_migrar['valor_reclamacion'] = df_migrar['valor_reclamacion'].replace('\xa0$ 2.240.000\xa0',2240000)
df_migrar['valor_reclamacion'] = df_migrar['valor_reclamacion'].fillna(0)

# %%
#Reviso de nuevo los valores únicos del campo.
df_migrar['valor_reclamacion'].unique()
# Out:
# array([0.0000000e+00, 4.6689800e+06, 9.2603000e+05, 3.6099000e+06,
#        1.7800000e+06, 6.1400000e+05, 9.0000000e+05, 2.0000000e+06,
#        4.0000000e+05, 1.8209470e+06, 1.0700000e+06, 1.1500000e+06,
#        9.5950000e+05, 5.5655000e+06, 1.3320000e+06, 4.0000000e+06,
#        1.7760000e+06, 5.5694000e+06, 5.8960000e+06, 5.7700000e+06,
#        2.0633000e+07, 3.5000000e+07, 1.4000000e+07, 5.0770000e+06,
#        1.1067800e+07, 1.6066900e+07, 1.4933924e+07, 4.8750000e+06,
#        6.0000000e+06, 1.3499900e+07, 2.2575000e+06, 2.0009600e+07,
#        3.0000000e+06, 1.5794341e+07, 5.9468000e+06, 7.6300000e+06,
#        1.8929216e+07, 2.7268700e+07, 6.8410000e+06, 6.9147000e+06,
#        3.4839980e+06, 2.6063000e+07, 1.1873000e+07, 1.6000000e+07,
#        4.7225000e+06, 5.0000000e+06, 1.2562500e+07, 1.8000000e+07,
#        2.0392000e+07, 1.8551001e+07, 2.5117500e+07, 6.7720000e+06,
#        1.6459200e+07, 5.4252100e+07, 1.1124500e+07, 9.3013660e+06,
#        1.8785000e+07, 2.1459301e+07, 9.0900000e+06, 7.6130000e+06,
#        1.2572500e+07, 7.1830000e+06, 1.0000000e+07, 1.9137000e+07,
#        7.4000000e+06, 5.5840000e+06, 1.4355400e+07, 2.4999000e+06,
#        1.3338500e+07, 6.9290000e+06, 5.1000000e+06, 1.7348000e+07,
#        1.0609550e+07, 1.4674000e+07, 1.0728000e+07, 7.8970000e+06,
#        9.3052000e+06, 7.2122000e+06, 6.9252140e+06, 1.5174851e+07,
#        4.7300000e+06, 1.4405000e+06, 5.3482000e+06, 9.8997000e+06,
#        5.5470000e+06, 2.3388700e+07, 3.8385000e+06, 7.2546000e+06,
#        1.0692000e+07, 1.8577200e+07, 1.0415000e+07, 1.5744450e+07,
#        3.2680000e+06, 1.6882000e+07, 1.1569300e+07, 1.0473479e+07,
#        5.1650000e+06, 4.5000000e+06, 1.0205000e+07, 5.3615000e+06,
#        1.5325200e+07, 1.1284059e+07, 3.9635000e+06, 4.3272550e+06,
#        1.1300000e+06, 1.1472200e+07, 1.1756500e+07, 1.5772000e+07,
#        1.1343900e+07, 7.0000000e+06, 6.6957000e+06, 1.6315000e+07,
#        1.5762500e+07, 2.1100000e+07, 3.9137000e+07, 5.6717000e+06,
#        2.5722200e+07, 4.0020000e+06, 2.8876010e+06, 1.4005651e+07,
#        3.5901210e+06, 1.0502500e+07, 1.5220000e+07, 5.3190000e+06,
#        1.0198898e+07, 1.5178651e+07, 5.7028320e+06, 3.4999000e+06,
#        8.5000000e+05, 3.0235000e+06, 2.4100000e+06, 3.4005000e+06,
#        2.6453790e+06, 1.3995000e+06, 4.4200000e+05, 1.4050000e+06,
#        6.7900000e+05, 9.4712000e+06, 1.0957400e+07, 1.5869000e+07,
#        1.7067200e+07, 2.2000000e+07, 2.6641000e+06, 1.1556381e+07,
#        1.4617500e+07, 1.7679500e+07, 7.8778000e+06, 7.5172040e+06,
#        1.1121000e+07, 3.7330000e+06, 7.5650000e+06, 1.5400000e+06,
#        7.4562500e+06, 3.0230000e+06, 1.2972000e+06, 1.0700000e+07,
#        9.1081490e+06, 1.1616500e+07, 9.5000000e+06, 5.1818000e+06,
#        1.1600000e+07, 4.7208000e+06, 7.2269300e+07, 5.4308000e+06,
#        1.8291000e+07, 3.8999000e+06, 5.9199196e+07, 1.0977500e+07,
#        5.1148000e+06, 2.0691180e+06, 8.6262500e+06, 2.2891964e+07,
#        4.1010000e+06, 3.2192755e+07, 3.6000000e+06, 7.0520000e+06,
#        4.0600000e+06, 1.6605200e+07, 1.0072497e+07, 2.0200000e+06,
#        7.7705000e+06, 1.3442400e+07, 3.8436400e+07, 1.0511000e+07,
#        3.9754000e+06, 4.9705000e+06, 5.3805000e+06, 2.5004050e+06,
#        3.1652400e+06, 4.1718000e+06, 2.1644000e+06, 1.0100000e+07,
#        5.3910000e+06, 2.9000000e+06, 1.2146708e+07, 8.0000000e+06,
#        9.4200000e+06, 8.0240000e+06, 6.9677280e+06, 4.7409990e+06,
#        5.6000000e+06, 6.8000000e+06, 4.5460000e+06, 4.4500000e+06,
#        5.2880000e+06, 5.9256000e+06, 1.9625222e+07, 7.0245000e+06,
#        1.3647000e+07, 2.9844000e+06, 9.2000000e+05, 7.9654000e+06,
#        9.7610000e+06, 2.1000000e+06, 1.0630000e+07, 1.0227900e+07,
#        4.5000000e+07, 1.0070850e+07, 1.3634150e+07, 2.5000000e+07,
#        1.3966000e+07, 1.5000000e+07, 1.0176000e+07, 2.3114010e+06,
#        9.9400000e+06, 1.2389410e+06, 2.5061600e+07, 1.5038000e+06,
#        2.3000000e+07, 2.2510000e+06, 5.7670000e+06, 2.6000000e+07,
#        7.9063000e+06, 7.1410000e+06, 2.1870000e+06, 6.4772000e+06,
#        2.3380000e+06, 1.2531000e+07, 2.7800000e+06, 4.0290000e+06,
#        1.2120700e+07, 9.2535000e+06, 1.1960000e+07, 1.1464500e+07,
#        1.2000000e+07, 6.0070000e+06, 1.2782400e+07, 1.9046200e+07,
#        1.9619100e+07, 1.5007200e+07, 1.5130000e+07, 3.6160000e+06,
#        4.2917540e+06, 1.6484000e+06, 1.4205000e+07, 1.2146000e+07,
#        1.4540000e+07, 5.4094500e+06, 3.8000000e+06, 2.7298045e+07,
#        1.2285000e+07, 3.4261000e+06, 3.0349710e+06, 3.5814000e+06,
#        4.3390000e+06, 2.5000000e+06, 3.5064000e+06, 4.8547000e+06,
#        3.1700000e+06, 3.5310000e+06, 2.4942000e+06, 2.8000000e+06,
#        1.0473000e+07, 5.2300000e+06, 1.8000000e+06, 5.4560000e+06,
#        1.9417000e+06, 1.7842000e+06, 6.9000000e+06, 3.2980000e+06,
#        8.5920000e+06, 2.4224500e+07, 5.3103000e+06, 3.7161500e+06,
#        1.0300000e+06, 2.3000000e+06, 1.6029000e+06, 6.0920000e+06,
#        1.5388000e+07, 1.2315000e+07, 2.0198000e+07, 7.1600000e+06,
#        8.0910000e+06, 5.0740000e+06, 2.8022700e+06, 3.5590000e+06,
#        9.2505700e+05, 3.5160000e+06, 8.0275000e+06, 2.8895000e+06,
#        6.1530000e+06, 1.6502000e+07, 2.5237000e+06, 9.4600000e+06,
#        8.3356360e+06, 1.2475200e+07, 1.9325000e+06, 7.8000000e+05,
#        9.8900000e+06, 7.0374000e+06, 6.6630000e+06, 5.5609000e+06,
#        7.5287000e+06, 6.0600000e+06, 8.2528000e+06, 1.0362000e+07,
#        8.4169500e+06, 8.3290000e+06, 2.3517200e+07, 2.5836600e+07,
#        1.1500000e+07, 6.1663020e+06, 9.0000000e+06, 5.4210000e+06,
#        5.5900000e+06, 5.5000000e+06, 5.2998000e+06, 2.0700000e+07,
#        3.7000000e+07, 1.5020000e+07, 6.1000000e+06, 5.1660000e+06,
#        2.0648198e+07, 5.3874760e+06, 1.5153800e+07, 1.0840000e+07,
#        1.6853000e+07, 7.5000000e+06, 1.1072530e+07, 6.5767000e+06,
#        5.2000000e+06, 6.4280000e+06, 5.5481500e+06, 5.3642000e+06,
#        1.1240600e+07, 1.6428000e+07, 5.0990000e+06, 9.7713000e+06,
#        5.0290000e+06, 1.1000000e+07, 1.0443500e+07, 1.2057505e+07,
#        4.1496800e+07, 1.4834535e+07, 1.8132000e+07, 1.0600000e+07,
#        1.0603731e+07, 5.2760000e+06, 1.7020000e+07, 1.1274000e+07,
#        7.7000000e+06, 1.4158150e+07, 7.3087590e+06, 8.5000000e+06,
#        8.9352000e+06, 6.5325000e+06, 6.2932000e+06, 1.6166000e+07,
#        9.1998000e+06, 9.1000000e+06, 6.0010000e+06, 1.0175000e+07,
#        9.4800000e+06, 1.4339000e+07, 5.1545000e+06, 1.1925000e+07,
#        9.0000000e+07, 7.8200000e+06, 1.9494500e+07, 7.8308000e+06,
#        7.7760000e+06, 6.2880000e+06, 1.5475000e+07, 1.1246300e+07,
#        9.9795800e+06, 2.0648900e+07, 9.1840000e+06, 6.4006000e+06,
#        5.7100000e+06, 1.8904000e+07, 1.1492050e+07, 8.7190000e+06,
#        8.6700000e+06, 8.8505000e+06, 9.1235000e+06, 7.1553000e+06,
#        3.2786000e+07, 4.8000000e+06, 7.1362000e+06, 5.5530000e+06,
#        7.1140000e+06, 1.2266500e+07, 1.2835800e+07, 8.3350000e+06,
#        1.7000000e+07, 1.2192000e+07, 1.0893600e+07, 3.2000000e+07,
#        5.8930000e+06, 2.1547000e+07, 1.5939800e+07, 7.8000000e+06,
#        1.4712500e+07, 5.4000000e+06, 1.1136392e+07, 6.0360000e+06,
#        7.1000000e+06, 1.3043520e+07, 6.4430000e+06, 7.5649000e+06,
#        5.0760000e+06, 1.5870000e+07, 7.0207550e+06, 1.0365000e+07,
#        6.2604800e+06, 9.9378000e+06, 6.7000000e+06, 1.4221000e+07,
#        1.0383800e+07, 1.5230000e+07, 1.0730000e+07, 1.0102800e+07,
#        9.2460000e+06, 1.3000000e+07, 9.9500000e+06, 1.8891600e+07,
#        1.0328000e+07, 2.5620536e+07, 7.0710000e+06, 7.9900000e+06,
#        5.6380000e+06, 1.9634000e+07, 1.8706600e+07, 1.0105000e+07,
#        9.8000000e+07, 6.9055000e+06, 1.2073500e+07, 4.6000000e+07,
#        6.2430000e+06, 1.1156060e+07, 7.4618000e+06, 3.1878000e+07,
#        2.8385500e+07, 2.0716000e+07, 5.6500000e+06, 1.0699000e+07,
#        7.9520000e+06, 4.6033280e+06, 2.4129818e+07, 1.6628000e+07,
#        7.5500000e+06, 8.9170000e+06, 2.0170000e+07, 1.1404100e+07,
#        9.0550000e+06, 5.8800000e+06, 1.1522000e+07, 1.4702950e+07,
#        1.2600000e+07, 1.8986180e+07, 3.2105035e+07, 5.1400000e+06,
#        8.4884000e+06, 1.0890000e+07, 1.9922172e+07, 3.2500000e+06,
#        4.9779000e+06, 3.1500000e+06, 4.6003460e+06, 7.5000000e+05,
#        3.6700000e+06, 3.5000000e+06, 3.3140000e+06, 1.1430000e+06,
#        9.6080000e+05, 4.6128000e+06, 2.9280000e+06, 3.5000000e+05,
#        4.3083000e+06, 3.2236000e+06, 4.9004000e+06, 4.4972480e+06,
#        2.0145380e+06, 4.2600000e+05, 2.3750000e+06, 2.4574000e+06,
#        3.7809250e+06, 7.9000000e+05, 2.2400000e+06, 4.4499000e+06,
#        3.2198000e+06, 1.5622000e+06, 1.0000000e+06, 1.3550000e+06,
#        7.3914000e+05, 7.0000000e+05, 1.8660000e+06, 2.8650000e+06,
#        6.0000000e+05, 2.7600000e+06, 1.9980000e+06, 1.3499000e+06,
#        3.0900000e+06, 3.8000000e+04, 1.7113200e+06, 3.1110000e+06,
#        3.7874000e+06, 1.4998000e+06, 6.2500000e+05, 1.2770000e+06,
#        3.2000000e+06, 1.3469000e+06, 3.9906840e+06, 4.4840000e+06,
#        3.8240000e+06, 1.6400000e+06, 3.9145000e+06, 1.5909000e+06,
#        4.5162500e+06, 2.5879000e+06, 2.8900000e+06, 3.9000000e+06,
#        4.7480000e+06, 4.6740000e+06, 4.1074000e+06, 2.5190000e+06,
#        2.3440000e+06, 1.1190000e+06, 2.9540000e+06, 2.3697500e+06,
#        4.6690000e+06, 2.7946000e+06, 1.5549000e+06, 2.2070000e+06,
#        2.5794000e+06, 7.9100000e+05, 1.4500000e+06, 1.6350000e+06,
#        4.5632000e+06, 4.6000000e+05, 2.7535000e+06, 2.5200000e+06,
#        8.5502000e+05, 3.7963820e+06, 3.5500000e+06, 3.6930000e+06,
#        1.8040000e+06, 1.5000000e+06, 5.6800000e+06, 8.4000000e+05,
#        3.3080000e+06, 5.5935000e+06, 3.9305000e+06, 3.7475000e+06,
#        2.8152450e+06, 4.9180000e+06, 2.4860000e+06, 3.9939500e+06,
#        2.3990000e+06, 4.0810000e+06, 3.9548000e+06, 2.5833000e+06,
#        2.6536000e+06, 2.2710000e+06, 4.3900000e+06, 4.0273000e+06,
#        4.9357000e+06, 4.4795000e+06, 5.5200000e+05, 2.5001000e+06,
#        4.0400000e+06, 2.1903000e+06, 4.3110000e+06, 2.0354000e+06,
#        2.8040000e+06, 1.1000000e+06, 1.5790000e+06, 2.5160000e+06,
#        1.5980000e+06, 4.8900000e+06, 1.2850000e+06, 3.2300000e+06,
#        6.9300000e+05, 4.3924000e+06, 1.8500000e+06, 4.3590000e+06,
#        2.1877500e+06, 3.0800000e+06, 1.4290000e+06, 4.8626020e+06,
#        1.0800000e+06, 2.2548800e+06, 1.1670000e+06, 1.8390000e+06,
#        3.7132000e+06, 3.4905000e+06, 4.0140000e+06, 2.2632620e+06,
#        2.4810000e+06, 4.1139340e+06, 1.7150000e+06, 3.2366000e+06,
#        2.0000000e+05, 5.2000000e+05, 2.4134000e+06, 1.0145000e+06,
#        1.8880000e+06, 3.7108650e+06, 3.9506400e+06, 3.1324000e+06,
#        1.3761000e+06, 1.8471000e+06, 3.4270000e+06, 1.3400000e+06,
#        4.8112000e+06, 3.8465000e+06, 3.4430000e+06, 2.9487000e+06,
#        3.8595000e+06, 3.1097010e+06, 3.0391000e+06, 2.2492000e+06,
#        2.4940000e+07, 1.4242000e+07, 1.0200000e+07, 6.2683000e+06,
#        7.9735500e+06, 6.8640000e+06, 5.2790000e+06, 1.9847500e+07,
#        2.1000000e+07, 1.2900000e+07, 9.2070000e+06, 7.8146000e+06,
#        3.0385500e+07, 6.2800000e+06, 5.9225000e+06, 6.9300000e+06,
#        9.7630000e+06, 1.1033807e+07, 1.2376000e+07, 5.9140000e+06,
#        1.6617500e+07, 1.0799800e+07, 1.0089844e+07, 1.4111150e+07,
#        6.6905000e+06, 7.6600000e+06, 1.3499975e+07, 9.9570000e+06,
#        6.0434600e+06, 8.6326060e+06, 7.2763140e+06, 9.9000000e+06,
#        7.1721000e+06, 2.2484306e+07, 2.2535744e+07, 5.7590000e+06,
#        1.4984955e+07, 1.6011823e+07, 1.3492300e+07, 1.4680000e+07,
#        1.9471797e+07, 1.0950000e+07, 8.4650000e+06, 1.6923672e+07,
#        6.4519000e+06, 1.1763400e+07, 1.7230000e+07, 4.5167000e+06,
#        3.1400000e+06, 1.2223454e+07, 1.3236252e+07, 5.0175340e+06,
#        8.7452500e+06, 5.2290000e+06, 1.1643774e+07, 9.3910000e+06,
#        5.3507000e+06, 5.0338000e+06, 6.3820000e+06, 6.0173000e+06,
#        6.7300000e+06, 1.5266500e+07, 9.7895000e+06, 5.8735000e+06,
#        6.4780000e+06, 9.3383880e+06, 9.5950000e+06, 1.7490000e+07,
#        2.4735000e+07])

# %%
#Una vez limpiada la columna valor_reclamacion, procededo a convertirla en tipo integer.
df_migrar['valor_reclamacion'] = df_migrar['valor_reclamacion'].astype(int)

# %%
#Convierto de objeto (string) a bool. 

#Reviso cuales son los valores que tiene el feature y que impide que el tipo de datos sea tomado como bool.
df_migrar['coexistencia'].unique()
# Out:
# array(['NO', 'SI', nan], dtype=object)

# %% [markdown]
# Los valores que arroja son <b>NO</b>, <b>SI</b>, <b>nan</b>

# %%
#Creo un diccionario para mapear los valores string (SI, NO)
diccionario_bool = {"NO":False,"SI":True}

#Reemplazo los valores por True, False respectivamente. Esto convertirá el campo a tipo bool.
df_migrar['coexistencia'] = df_migrar['coexistencia'].map(diccionario_bool)
df_migrar['coexistencia'] = df_migrar['coexistencia'] == True

# %%
#Verifico si se hizo la conversión.
df_migrar['coexistencia'].value_counts()
# Out:
# False    1437
# True      272
# Name: coexistencia, dtype: int64

# %%
#Reviso los tipos de datos que tiene cada columna, y verificar si hay compatibilidad con el tipo de datos en la
#base de datos de la aplicación. 

#Generamos un dataframe con los tipos de datos de cada columna en el dataset actual.
df_migrar_tipos_datos = pd.DataFrame(df_migrar.dtypes)

#Agregamos una columna adicional, con la cual visualizar el tipo de dato que se requiere en la base de datos a mnigrar.
diccionario_tipo_datos = dict(zip(df_columnas_definitivas['nombre_campo'], df_columnas_definitivas['tipo_dato']))
df_migrar_tipos_datos['tipo_dato'] = df_migrar_tipos_datos.index.map(diccionario_tipo_datos)

#Vamos a identificar los features que no comparten el mismo tipo de datos para examinarlos posteriormente.

mask = df_migrar_tipos_datos[0] != df_migrar_tipos_datos['tipo_dato']

df_migrar_tipos_datos[mask]
# Out:
#              0 tipo_dato
# Item_no  int64   float64
# year     int64       NaN

# %% [markdown]
# #### objetivo 2, cumplido.
#
# ## PARTE 3 - Garantizar que existan valores únicos para los features categorícos, y que los mismos sean coincidentes con los estandarizados en la aplicación.
#
# Objetivos:
#
# 1. Identificar valores únicos para cada campo categoríco. Los campos categorícos se identificaron con base en la aplicación, y los valores estandar que se manejan para estos campos.
#
# 2. Reemplazar los valores no coincidentes por los valores estandar que maneja la aplicación.

# %%
#Reviso las columnas que tiene el dataframe df_migrar.
df_migrar.columns
# Out:
# Index(['Item_no', 'cantidad_polizas', 'no_poliza', 'numero_zonic',
#        'ciudad_asegurado', 'departamento_asegurado', 'direccion_asegurado',
#        'nombre_asegurado', 'cedula_asegurado', 'producto_poliza',
#        'categoria_reclamacion', 'siniestro', 'fecha_siniestro', 'fecha_aviso',
#        'fecha_aprobacion_pago', 'fecha_definicion', 'fecha_aviso_ingetech',
#        'mes', 'fecha_inspeccion', 'fecha_entrega_informe_final',
#        'fecha_informe_final', 'responsable', 'valor_reclamacion', 'reserva',
#        'honorarios', 'causa', 'cobertura', 'estado', 'observacion_1',
#        'observacion_2', 'notas', 'factura', 'inspector', 'ajustador',
#        'telefono_asegurado', 'coexistencia', 'bienes', 'descripcion_siniestro',
#        'credito_poliza', 'vigencia_desde', 'vigencia_hasta', 'banco',
#        'numero_cuenta_banco', 'forma_pago', 'year'],
#       dtype='object')

# %%
#creo una lista con los campos que tienen valores únicos, y creo la variable diccionario, la cual inicialmente estará vacia.
campos_categoricos = ['departamento_asegurado', 'ciudad_asegurado', 'producto_poliza', 'categoria_reclamacion', 'cobertura', 'bienes', 'estado', 'observacion_1']
diccionario = {}

#Extraigo cada uno de los valores únicos que tienen los campos definidos en la lista campos_categoricos.
for campo in campos_categoricos:
    diccionario[campo] = df_migrar[campo].unique()

# %% [markdown]
# #### Objetivo 1, cumplido

# %%
#Exploro los valores únicos de 'departamento_asegurado', 
diccionario['departamento_asegurado']
# Out:
# array(['CHOCO', 'VALLE DEL CAUCA', 'ANTIOQUIA', 'CORDOBA', 'PUTUMAYO',
#        'BOLIVAR', 'ATLÁNTICO', 'NARIÑO', 'MAGDALENA', 'CAUCA', 'CALDAS',
#        'RISARALDA', 'CUNDINAMARCA', 'HUILA', 'TOLIMA ', 'QUINDIO',
#        'CESAR', 'GUAJIRA', 'META', 'CAQUETA', 'TOLIMA', 'ARMENIA',
#        'HUILA ', 'NORTE DE SANTANDER', 'BOYACÁ', 'SAN JOSE DEL GUAVIARE',
#        'GUAVIARE', 'SANTANDER', 'MEDELLIN', 'MANIZALES', 'AMAZONAS',
#        'CALDAS ', 'ARAUCA', 'CAQUETÁ', 'QUINDIO ', 'NORTE DE SANTANDER ',
#        'CAUCA ', nan], dtype=object)

# %%
# creo un diccionario con los valores correctos pra el campo "departamento_asegurado"

d_departamento = {'CHOCO':'Chocó','CHOCÓ':'Chocó','VALLE DEL CAUCA':'Valle del Cauca', 'ANTIOQUIA':'Antioquia', 'CORDOBA':'Córdoba', 
                  'PUTUMAYO':'Putumayo', 'BOLIVAR':'Bolivar', 'ATLÁNTICO':'Atlántico', 'NARIÑO':'Nariño', 'HUILA':'Huila',
                  'RISARALDA':'Risaralda','QUINDIO':'Quindío', 'TOLIMA':'Tolima', 'CALDAS':'Caldas','BOYACÁ':'Boyacá',
                  'MAGDALENA':'Magdalena','CAUCA':'Cauca', 'CUNDINAMARCA':'Cundinamarca', 'CAQUETÁ':'Caquetá','META':'Meta',
                  'CESAR':'Cesar', 'GUAJIRA':'La Guajira','ARMENIA':'Quindío', 'NORTE DE SANTANDER':'Norte de Santander',
                  'SAN JOSE DEL GUAVIARE':'Guaviare','GUAVIARE':'Guaviare', 'SANTANDER':'Santander', 'MEDELLIN':'Antiquía',
                  'MANIZALES':'Caldas','AMAZONAS':'Amazonas', 'CALDAS ':'Caldas', 'ARAUCA':'Arauca', 'NORTE DE SANTANDER ':'Norte de Santander',
                  'CAUCA ':'Cauca'}

#Realizo el reemplazo de los valores
df_migrar['departamento_asegurado'] = df_migrar['departamento_asegurado'].map(d_departamento)

#Reviso de nuevo los valores únicos de este feature para verificar que el cambio se haya dado
df_migrar['departamento_asegurado'].unique()
# Out:
# array(['Chocó', 'Valle del Cauca', 'Antioquia', 'Córdoba', 'Putumayo',
#        'Bolivar', 'Atlántico', 'Nariño', 'Magdalena', 'Cauca', 'Caldas',
#        'Risaralda', 'Cundinamarca', 'Huila', nan, 'Quindío', 'Cesar',
#        'La Guajira', 'Meta', 'Tolima', 'Norte de Santander', 'Boyacá',
#        'Guaviare', 'Santander', 'Antiquía', 'Amazonas', 'Arauca',
#        'Caquetá'], dtype=object)

# %% [markdown]
# El campo <b>departamento_asegurado</b> se encuentra ajustado.

# %%
#Exploro los valores únicos de 'ciudad_asegurado', 
diccionario['ciudad_asegurado']
# Out:
# array(['QUIBDO', 'ISTMINA', 'ROLDANILLO', 'APARTADÓ', 'TURBACO', 'TURBO',
#        'CAUCASIA', 'LLORO', 'LORICA', 'DOÑA JOSEFA', 'PUERTO ASIS',
#        'PUERTO CAICEDO', 'CARTAGENA', 'SEVILLA', 'CAICEDONIA', 'MALAMBO',
#        'CALI', 'BORAUDO', 'QUBDO', 'TUMACO', 'COLON', 'SANTA MARTA',
#        'BUENOS AIRES', 'MARMATO', 'PEREIRA', 'VERGARA', 'GARZÓN ',
#        'PLANADAS', 'PATIA', 'PIENDAMO', 'CHIA', 'POPAYÁN',
#        'QUEBRADANEGRA', 'BUENAVENTURA', 'EL TAMBO', 'ARMENIA ',
#        'DOSQUEBRADAS', 'PURIFICACIÓN', 'PURACE', 'BOSCONIA', 'RIOBLANCO',
#        'VILLAGARZON', 'ORTEGA ', 'SANTANDER DE QUILICHAO',
#        'SANTA ROSA DE CABAL', 'PITALITO', 'DIBULLA', 'CARTAGO',
#        'PIENDAMO ', 'MARIQUITA', 'ARBOLEDA', 'VILLAVICENCIO',
#        'VILLA RICA ', 'CANDELARIA', 'GUACHENE ', 'CAJIBIO', 'FONSECA',
#        'ALCALA ', 'ISNOS', 'MONTENEGRO', 'SASAIMA', 'SAN PABLO ',
#        'RIONEGRO', 'VILLETA', 'RICAURTE', 'FLORENCIA', 'CHINCHINA',
#        'LA VEGA', 'FLANDES ', 'TUQUERRES', 'SAN ANDRES DE TUMACO',
#        'QUIMBAYA', 'PUERTO TEJADA', 'MIRANDA', 'MANIZALES', 'QUINDIO',
#        'PEREIRA ', 'ANSERMANUEVO', 'LA DORADA', 'ARMENIA', 'ACEVEDO',
#        'PASTO', 'TULUA', 'CHAPARRAL ', 'SOACHA', 'RIOSUCIO', 'FLANDES',
#        'BOGOTÁ', 'CUCUTA', 'BUGALAGRANDE', 'ORTEGA', 'SOGAMOSO',
#        'ANSERMA', 'GIGANTE', 'UTICA', 'SUPIA', 'SUPIA ', 'ANDAGOYA',
#        'PRADERA', 'PUERTO BOYACÁ', 'BARRANCAS ', 'ESPINAL', 'SABANALARGA',
#        'MOCOA', 'NORCASIA', 'EL RETORNO', 'INZA', 'VILLA MARIA',
#        'VALLE DE SAN JUAN', 'PITALITO ', 'PALMIRA', 'ATACO', 'SUAREZ',
#        'LA PAZ', 'CALARCA', 'SAN VICENTE DEL CAGUAN', 'PAEZ',
#        'PUERTO CONCORDIA', 'SAN AGUSTIN', 'RIOHACHA', 'MONTENEGRO ',
#        'SAN JOSE DEL GUAVIARE', 'LA CEJA', 'SAN JOSE ', 'RIOSUCIO ',
#        'SILVANIA', 'BELLO', 'ITAGUI', 'NIMAIMA', 'PUERTO GUZMAN',
#        'CONDOTO', 'EL PAUJIL', 'BOLIVAR', 'CHIGORODO', 'BARRANCABERMEJA',
#        'JAMUNDI', 'CALOTO', 'FUNZA', 'VILLAMARIA', 'SAN ANDRES SOTAVENTO',
#        'SAMACÁ', 'CALOTO ', 'ANTIOQUIA ', 'CALDAS', 'ZONA BANANERA',
#        'SALDANA', 'CURILLO', 'BARANOA', 'OCAÑA', 'ZARZAL', 'LA PLATA',
#        'NILO', 'SILVIA', 'MEDELLIN', 'PALESTINA', 'SAHAGUN', 'PASCA',
#        'CHAPARRAL', 'TIMBIO', 'GUARNE', 'YUMBO ', 'TANGUA', 'MONITOS',
#        'TIBANÁ', 'QUINCHIA', 'NEIVA', 'GRANADA', 'BUCARAMANGA', 'COGUA',
#        'MOCOA ', 'MEDELLIN ', 'BELLO ', 'LETICIA ', 'TRUJILLO',
#        'ESPINAL ', 'TULUA ', 'IBAGUE', 'ACACIAS ', 'ANSERMA ', 'CIRCASIA',
#        'TUNJA', 'LA ARGENTINA', 'GUACHENE', 'PUERTO LIBERTADOR',
#        'PUEBLOVIEJO', 'PUERTO GAITAN', 'FILANDIA', 'REPELON ', 'GENOVA',
#        'NOCAIMA', 'SAN JOSE DEL FRAGUA', 'CIENAGA', 'SANTA ANA', 'TARQUI',
#        'MALLAMA', 'COMBITA', 'FUSAGASUGA', 'QUIBDÓ', 'TIMANA',
#        'VILLAGARZÓN', 'VILLARICA', 'IPIALES', 'ARAUQUITA', 'PUEBLO RICO',
#        'PUPIALES', 'CALARCÁ', 'LEBRIJA', 'QUEBRADANEGRA ', 'GARZON ',
#        'PATIA ', 'LA UNION ', 'SAN ANTONIO', nan], dtype=object)

# %% [markdown]
# Dada la gran cantidad de valores que son necesarios convertir, es necesario crear un diccionario a partir de la tabla
# que codifica los municipios en el sistema de información, de tal manera que se pueda generar un mecanismo para facilitar
# el reemplazo del nombre del municipio como está escrito, con el nombre de municipio como debería estar escrito al migrar
# a la base de datos de la aplicación.

# %%
#Creo un diccionario de municipios.
municipio = pd.read_excel("cod_municipios.xls")
municipio['clave_minuscula'] = municipio["nombre_municipio"].str.replace(" ","").str.lower().apply(str)
municipio['clave_minuscula'] = municipio['clave_minuscula'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')

dic_municipios = dict(np.array(municipio[['clave_minuscula','nombre_municipio']]))
dic_municipios
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# {'belendeumbria': 'Belen de umbria',
#  'bello': 'Bello',
#  'belmira': 'Belmira',
#  'beltran': 'Beltran',
#  'berbeo': 'Berbeo',
#  'betania': 'Betania',
#  'beteitiva': 'Beteitiva',
#  'betulia': 'Betulia',
#  'bituima': 'Bituima',
#  'boavita': 'Boavita',
#  'bochalema': 'Bochalema',
#  'bogotad.c.': 'Bogotá D.C.',
#  'bojaca': 'Bojaca',
#  'bojaya(bellavista)': 'Bojaya (bellavista)',
#  'bolivar': 'Bolivar',
#  'bosa': 'Bosa',
#  'bosconia': 'Bosconia',
#  'boyaca': 'Boyaca',
#  'boyaca-departamento': 'Boyacá - DEPARTAMENTO',
#  'briceno': 'Briceño',
#  'bucaramanga': 'Bucaramanga',
#  'bucarasica': 'Bucarasica',
#  'buenaventura': 'Buenaventura',
#  'buenavista': 'Buenavista',
#  'buenosaires': 'Buenos aires',
#  'buesaco': 'Buesaco',
#  'buga': 'Buga',
#  'bugalagrande': 'Bugalagrande',
#  'buritica': 'Buritica',
#  'busbanza': 'Busbanza',
#  'cabrera': 'Cabrera',
#  'cabuyaro': 'Cabuyaro',
#  'cacahual': 'Cacahual',
#  'caceres': 'Caceres',
#  'cachipay': 'Cachipay',
#  'cachira': 'Cachira',
#  'cacota': 'Cacota',
#  'caicedo': 'Caicedo',
#  'caicedonia': 'Caicedonia',
#  'caimito': 'Caimito',
#  'cajamarca': 'Cajamarca',
#  'cajibio': 'Cajibio',
#  'cajica': 'Cajica',
#  'calamar': 'Calamar',
#  'calarca': 'Calarca',
#  'caldas': 'Caldas',
#  'caldas-departamento': 'Caldas - DEPARTAMENTO',
#  'caldono': 'Caldono',
#  'cali(santiagodecali)': 'Cali (santiago de cali)',
#  'california': 'California',
#  'calima(darien)': 'Calima (darien)',
#  'caloto': 'Caloto',
#  'campamento': 'Campamento',
#  'campodelacruz': 'Campo de la cruz',
#  'campoalegre': 'Campoalegre',
#  'campohermoso': 'Campohermoso',
#  'canalete': 'Canalete',
#  'candelaria': 'Candelaria',
#  'cantagallo': 'Cantagallo',
#  'cantondesanpablo(managru)': 'Canton de san pablo (managru)',
#  'canasgordas': 'Cañasgordas',
#  'caparrapi': 'Caparrapi',
#  'capitanejo': 'Capitanejo',
#  'caqueza': 'Caqueza',
#  'caracoli': 'Caracoli',
#  'caramanta': 'Caramanta',
#  'carcasi': 'Carcasi',
#  'carepa': 'Carepa',
#  'carmenapicala': 'Carmen apicala',
#  'carmendecarupa': 'Carmen de carupa',
#  'carmendeviboral': 'Carmen de viboral',
#  'carolina': 'Carolina',
#  'cartagena': 'Cartagena',
#  'cartagenadelchaira': 'Cartagena del chaira',
#  'cartago': 'Cartago',
#  'caruru': 'Caruru',
#  'casabianca': 'Casabianca',
#  'casanare-departamento': 'Casanare - DEPARTAMENTO',
#  'castillalanueva': 'Castilla la nueva',
#  'cauca-departamento': 'Cauca - DEPARTAMENTO',
#  'caucasia': 'Caucasia',
#  'cepita': 'Cepita',
#  'cerete': 'Cerete',
#  'cerinza': 'Cerinza',
#  'cerrito': 'Cerrito',
#  'cerrosanantonio': 'Cerro san antonio',
#  'cesar-departamento': 'Cesar - DEPARTAMENTO',
#  'chachagui': 'Chachagui',
#  'chaguani': 'Chaguani',
#  'chalan': 'Chalan',
#  'chameza': 'Chameza',
#  'chaparral': 'Chaparral',
#  'chapinero': 'Chapinero',
#  'charala': 'Charala',
#  'charta': 'Charta',
#  'chia': 'Chia',
#  'chigorodo': 'Chigorodo',
#  'chima': 'Chima',
#  'chimichagua': 'Chimichagua',
#  'chinacota': 'Chinacota',
#  'chinavita': 'Chinavita',
#  'chinchina': 'Chinchina',
#  'chinu': 'Chinu',
#  'chipaque': 'Chipaque',
#  'chipata': 'Chipata',
#  'chiquinquira': 'Chiquinquira',
#  'chiquiza': 'Chiquiza',
#  'chiriguana': 'Chiriguana',
#  'chiscas': 'Chiscas',
#  'chita': 'Chita',
#  'chitaga': 'Chitaga',
#  'chitaraque': 'Chitaraque',
#  'chivata': 'Chivata',
#  'chivolo': 'Chivolo',
#  'chivor': 'Chivor',
#  'choachi': 'Choachi',
#  'choconta': 'Choconta',
#  'cicuco': 'Cicuco',
#  'cienaga': 'Cienaga',
#  'cienagadeoro': 'Cienaga de oro',
#  'cienega': 'Cienega',
#  'cimitarra': 'Cimitarra',
#  'circasia': 'Circasia',
#  'cisneros': 'Cisneros',
#  'ciudadbolivar': 'Ciudad Bolivar',
#  'clemencia': 'Clemencia',
#  'cocorna': 'Cocorna',
#  'coello': 'Coello',
#  'cogua': 'Cogua',
#  'colombia': 'Colombia',
#  'colon': 'Colon',
#  'colon(genova)': 'Colon (genova)',
#  'coloso(ricaurte)': 'Coloso (ricaurte)',
#  'combita': 'Combita',
#  'concepcion': 'Concepcion',
#  'concordia': 'Concordia',
#  'condoto': 'Condoto',
#  'confines': 'Confines',
#  'consaca': 'Consaca',
#  'contadero': 'Contadero',
#  'contratacion': 'Contratacion',
#  'convencion': 'Convencion',
#  'copacabana': 'Copacabana',
#  'coper': 'Coper',
#  'cordoba': 'Cordoba',
#  'corinto': 'Corinto',
#  'coromoro': 'Coromoro',
#  'corozal': 'Corozal',
#  'corrales': 'Corrales',
#  'cota': 'Cota',
#  'cotorra': 'Cotorra',
#  'covarachia': 'Covarachia',
#  'coyaima': 'Coyaima',
#  'cravonorte': 'Cravo norte',
#  'cuaspud(carlosama)': 'Cuaspud (carlosama)',
#  'cubara': 'Cubara',
#  'cucaita': 'Cucaita',
#  'cucunuba': 'Cucunuba',
#  'cucuta': 'Cucuta',
#  'cucutilla': 'Cucutilla',
#  'cuitiva': 'Cuitiva',
#  'cumaral': 'Cumaral',
#  'cumaribo': 'Cumaribo',
#  'cumbal': 'Cumbal',
#  'cumbitara': 'Cumbitara',
#  'cunday': 'Cunday',
#  'curillo': 'Curillo',
#  'curiti': 'Curiti',
#  'curumani': 'Curumani',
#  'dabeiba': 'Dabeiba',
#  'dagua': 'Dagua',
#  'dibulla': 'Dibulla',
#  'distraccion': 'Distraccion',
#  'dolores': 'Dolores',
#  'donmatias': 'Don matias',
#  'dosquebradas': 'Dos quebradas',
#  'duitama': 'Duitama',
#  'durania': 'Durania',
#  'ebejico': 'Ebejico',
#  'elaguila': 'El aguila',
#  'elbagre': 'El bagre',
#  'elbanco': 'El banco',
#  'elcairo': 'El cairo',
#  'elcalvario': 'El calvario',
#  'elcarmen': 'El carmen',
#  'elcarmendeatrato': 'El carmen de atrato',
#  'elcarmendebolivar': 'El carmen de bolivar',
#  'elcarmendechucury': 'El carmen de chucury',
#  'elcastillo': 'El castillo',
#  'elcerrito': 'El cerrito',
#  'elcharco': 'El charco',
#  'elcocuy': 'El cocuy',
#  'elcolegio': 'El colegio',
#  'elcopey': 'El copey',
#  'eldoncello': 'El doncello',
#  'eldorado': 'El dorado',
#  'eldovio': 'El dovio',
#  'elencanto': 'El encanto',
#  'elespino': 'El espino',
#  'elguacamayo': 'El guacamayo',
#  'elguamo': 'El guamo',
#  'elmolino': 'El molino',
#  'elpaso': 'El paso',
#  'elpaujil': 'El paujil',
#  'elpenol': 'El peñol',
#  'elpenon': 'El peñon',
#  'elpinon': 'El piñon',
#  'elplayon': 'El playon',
#  'elreten': 'El reten',
#  'elretorno': 'El retorno',
#  'elrosal': 'El rosal',
#  'elrosario': 'El rosario',
#  'eltablon': 'El tablon',
#  'eltambo': 'EL TAMBO',
#  'eltarra': 'El tarra',
#  'elzulia': 'El zulia',
#  'elias': 'Elias',
#  'encino': 'Encino',
#  'enciso': 'Enciso',
#  'engativa': 'Engativa',
#  'entrerrios': 'Entrerrios',
#  'envigado': 'Envigado',
#  'espinal': 'Espinal',
#  'facatativa': 'Facatativa',
#  'falan': 'Falan',
#  'filadelfia': 'Filadelfia',
#  'filandia': 'Filandia',
#  'firavitoba': 'Firavitoba',
#  'flandes': 'Flandes',
#  'florencia': 'Florencia',
#  'floresta': 'Floresta',
#  'florian': 'Florian',
#  'florida': 'Florida',
#  'floridablanca': 'Floridablanca',
#  'fomeque': 'Fomeque',
#  'fonseca': 'Fonseca',
#  'fontibon': 'Fontibon',
#  'fortul': 'Fortul',
#  'fosca': 'Fosca',
#  'franciscopizarro(salahonda)': 'Francisco pizarro (salahonda)',
#  'fredonia': 'Fredonia',
#  'fresno': 'Fresno',
#  'frontino': 'Frontino',
#  'fuentedeoro': 'Fuente de oro',
#  'fundacion': 'Fundacion',
#  'funes': 'Funes',
#  'funza': 'Funza',
#  'fuquene': 'Fuquene',
#  'fusagasuga': 'Fusagasuga',
#  'gachala': 'Gachala',
#  'gachancipa': 'Gachancipa',
#  'gachantiva': 'Gachantiva',
#  'gacheta': 'Gacheta',
#  'galan': 'Galan',
#  'galapa': 'Galapa',
#  'galeras(nuevagranada)': 'Galeras (nueva granada)',
#  'gama': 'Gama',
#  'gamarra': 'Gamarra',
#  'gambita': 'Gambita',
#  'gameza': 'Gameza',
#  'garagoa': 'Garagoa',
#  'garzon': 'Garzon',
#  'genova': 'Genova',
#  'gigante': 'Gigante',
#  'ginebra': 'Ginebra',
#  'giraldo': 'Giraldo',
#  'girardot': 'Girardot',
#  'girardota': 'Girardota',
#  'giron': 'Giron',
#  'gomezplata': 'Gomez plata',
#  'gonzalez': 'Gonzalez',
#  'gramalote': 'Gramalote',
#  'granada': 'Granada',
#  'guaca': 'Guaca',
#  'guacamayas': 'Guacamayas',
#  'guacari': 'Guacari',
#  'guacheta': 'Guacheta',
#  'guachucal': 'Guachucal',
#  'guadalupe': 'Guadalupe',
#  'guaduas': 'Guaduas',
#  'guaitarilla': 'Guaitarilla',
#  'gualmatan': 'Gualmatan',
#  'guamal': 'Guamal',
#  'guamo': 'Guamo',
#  'guapi': 'Guapi',
#  'guapota': 'Guapota',
#  'guaranda': 'Guaranda',
#  'guarne': 'Guarne',
#  'guasca': 'Guasca',
#  'guatape': 'Guatape',
#  'guataqui': 'Guataqui',
#  'guatavita': 'Guatavita',
#  'guateque': 'Guateque',
#  'guatica': 'Guatica',
#  'guavata': 'Guavata',
#  'guayabaldesiquima': 'Guayabal de siquima',
#  'guayabetal': 'Guayabetal',
#  'guayata': 'Guayata',
#  'guepsa': 'Guepsa',
#  'guican': 'Guican',
#  'gutierrez': 'Gutierrez',
#  'hacari': 'Hacari',
#  'hatillodeloba': 'Hatillo de loba',
#  'hato': 'Hato',
#  'hatocorozal': 'Hato corozal',
#  'hatonuevo': 'Hatonuevo',
#  'heliconia': 'Heliconia',
#  'herran': 'Herran',
#  'herveo': 'Herveo',
#  'hispania': 'Hispania',
#  'hobo': 'Hobo',
#  'honda': 'Honda',
#  'huila-departamento': 'Huila - DEPARTAMENTO',
#  'ibague': 'Ibague',
#  'icononzo': 'Icononzo',
#  'iles': 'Iles',
#  'imues': 'Imues',
#  'inza': 'Inza',
#  'ipiales': 'Ipiales',
#  'iquira': 'Iquira',
#  'isnos(sanjosedeisnos)': 'Isnos (san jose de isnos)',
#  'istmina': 'Istmina',
#  'itagui': 'Itagui',
#  'ituango': 'Ituango',
#  'iza': 'Iza',
#  'jambalo': 'Jambalo',
#  'jamundi': 'Jamundi',
#  'jardin': 'Jardin',
#  'jenesano': 'Jenesano',
#  'jerico': 'Jerico',
#  'jerusalen': 'Jerusalen',
#  'jesusmaria': 'Jesus maria',
#  'jordan': 'Jordan',
#  'juandeacosta': 'Juan de acosta',
#  'junin': 'Junin',
#  'jurado': 'Jurado',
#  'kennedy': 'Kennedy',
#  'laapartada': 'La apartada',
#  'laargentina': 'La argentina',
#  'labelleza': 'La belleza',
#  'lacalera': 'La calera',
#  'lacapilla': 'La capilla',
#  'laceja': 'La ceja',
#  'lacelia': 'La celia',
#  'lachorrera': 'La chorrera',
#  'lacruz': 'La cruz',
#  'lacumbre': 'La cumbre',
#  'ladorada': 'La dorada',
#  'laesperanza': 'La esperanza',
#  'laestrella': 'La estrella',
#  'laflorida': 'La florida',
#  'lagloria': 'La gloria',
#  'laguadalupe': 'La guadalupe',
#  'laguajira-departamento': 'La Guajira - DEPARTAMENTO',
#  'lahormiga(valledelguamuez)': 'La hormiga (valle del guamuez)',
#  'lajaguadelpilar': 'La jagua del pilar',
#  'lajaguaibirico': 'La jagua ibirico',
#  'lallanada': 'La llanada',
#  'lamacarena': 'La macarena',
#  'lamerced': 'La merced',
#  'lamesa': 'La mesa',
#  'lamontanita': 'La montañita',
#  'lapalma': 'La palma',
#  'lapaz': 'La paz',
#  'lapaz(robles)': 'La paz (robles)',
#  'lapedrera': 'La pedrera',
#  'lapena': 'La peña',
#  'lapintada': 'La pintada',
#  'laplata': 'La plata',
#  'laplaya': 'La playa',
#  'laprimavera': 'La primavera',
#  'manaure(balcondelcesar)': 'Manaure (balcon del cesar)',
#  'mani': 'Mani',
#  'manizales': 'Manizales',
#  'manta': 'Manta',
#  'manzanares': 'Manzanares',
#  'mapiripan': 'Mapiripan',
#  'margarita': 'Margarita',
#  'marialabaja': 'Maria la baja',
#  'marinilla': 'Marinilla',
#  'maripi': 'Maripi',
#  'mariquita': 'Mariquita',
#  'marmato': 'Marmato',
#  'marquetalia': 'Marquetalia',
#  'marsella': 'Marsella',
#  'martires': 'Martires',
#  'marulanda': 'Marulanda',
#  'nan': nan,
#  'lasalina': 'La salina',
#  'lasierra': 'La sierra',
#  'latebaida': 'La tebaida',
#  'latola': 'La tola',
#  'launion': 'La union',
#  'lauribe': 'La uribe',
#  'lauvita': 'La uvita',
#  'lavega': 'La vega',
#  'lavictoria': 'La victoria',
#  'lavirginia': 'La virginia',
#  'labateca': 'Labateca',
#  'labranzagrande': 'Labranzagrande',
#  'landazuri': 'Landazuri',
#  'lebrija': 'Lebrija',
#  'leiva': 'Leiva',
#  'lejanias': 'Lejanias',
#  'lenguazaque': 'Lenguazaque',
#  'lerida': 'Lerida',
#  'leticia': 'Leticia',
#  'libano': 'Libano',
#  'liborina': 'Liborina',
#  'linares': 'Linares',
#  'litoraldelbajosanjuan(santagenovevadedocordo)': 'Litoral del bajo san juan (santa genoveva de docordo)',
#  'lloro': 'Lloro',
#  'lopez(micay)': 'Lopez (micay)',
#  'lorica': 'Lorica',
#  'losandes(sotomayor)': 'Los andes (sotomayor)',
#  'loscordobas': 'Los cordobas',
#  'lospalmitos': 'Los palmitos',
#  'lospatios': 'Los patios',
#  'lossantos': 'Los santos',
#  'lourdes': 'Lourdes',
#  'luruaco': 'Luruaco',
#  'macanal': 'Macanal',
#  'macaravita': 'Macaravita',
#  'maceo': 'Maceo',
#  'macheta': 'Macheta',
#  'madrid': 'Madrid',
#  'magangue': 'Magangue',
#  'magui(payan)': 'Magui (payan)',
#  'mahates': 'Mahates',
#  'maicao': 'Maicao',
#  'majagual': 'Majagual',
#  'malaga': 'Malaga',
#  'malambo': 'Malambo',
#  'mallama(piedrancha)': 'Mallama (piedrancha)',
#  'manati': 'Manati',
#  'manaure': 'Manaure',
#  '_': '_',
#  'abejorral': 'Abejorral',
#  'abrego': 'Abrego',
#  'abriaqui': 'Abriaqui',
#  'acacias': 'Acacias',
#  'acandi': 'Acandi',
#  'acevedo': 'Acevedo',
#  'achi': 'Achi',
#  'agrado': 'Agrado',
#  'aguadedios': 'Agua de dios',
#  'aguachica': 'Aguachica',
#  'aguada': 'Aguada',
#  'aguadas': 'Aguadas',
#  'aguazul': 'Aguazul',
#  'agustincodazzi': 'Agustin codazzi',
#  'aipe': 'Aipe',
#  'alban': 'Alban',
#  'alban(sanjose)': 'Alban (san jose)',
#  'albania': 'Albania',
#  'alcala': 'Alcala',
#  'aldana': 'Aldana',
#  'alejandria': 'Alejandria',
#  'algarrobo': 'Algarrobo',
#  'algeciras': 'Algeciras',
#  'almaguer': 'Almaguer',
#  'almeida': 'Almeida',
#  'alpujarra': 'Alpujarra',
#  'altamira': 'Altamira',
#  'altobaudo(piedepato)': 'Alto baudo (pie de pato)',
#  'altosdelrosario': 'Altos del rosario',
#  'alvarado': 'Alvarado',
#  'amaga': 'Amaga',
#  'amalfi': 'Amalfi',
#  'ambalema': 'Ambalema',
#  'anapoima': 'Anapoima',
#  'ancuya': 'Ancuya',
#  'andalucia': 'Andalucia',
#  'andes': 'Andes',
#  'angelopolis': 'Angelopolis',
#  'angostura': 'Angostura',
#  'anolaima': 'Anolaima',
#  'anori': 'Anori',
#  'anserma': 'Anserma',
#  'ansermanuevo': 'Ansermanuevo',
#  'antioquia': 'Antioquia',
#  'antonionarino': 'Antonio Nariño',
#  'anza': 'Anza',
#  'anzoategui': 'Anzoategui',
#  'apartado': 'Apartado',
#  'apia': 'Apia',
#  'apulo(rafaelreyes)': 'Apulo (rafael reyes)',
#  'aquitania': 'Aquitania',
#  'aracataca': 'Aracataca',
#  'aranzazu': 'Aranzazu',
#  'aratoca': 'Aratoca',
#  'arauca': 'Arauca',
#  'arauquita': 'Arauquita',
#  'arbelaez': 'Arbelaez',
#  'arboleda(berruecos)': 'Arboleda (berruecos)',
#  'arboledas': 'Arboledas',
#  'arboletes': 'Arboletes',
#  'arcabuco': 'Arcabuco',
#  'arenal': 'Arenal',
#  'argelia': 'Argelia',
#  'ariguani(eldificil)': 'Ariguani (el dificil)',
#  'arjona': 'Arjona',
#  'armenia': 'Armenia',
#  'armero(guayabal)': 'Armero (guayabal)',
#  'arroyohondo': 'Arroyohondo',
#  'astrea': 'Astrea',
#  'ataco': 'Ataco',
#  'atlantico': 'Atlántico',
#  'atrato': 'Atrato',
#  'ayapel': 'Ayapel',
#  'bagado': 'Bagado',
#  'bahiasolano(mutis)': 'Bahia solano (mutis)',
#  'bajobaudo(pizarro)': 'Bajo baudo (pizarro)',
#  'balboa': 'Balboa',
#  'baranoa': 'Baranoa',
#  'baraya': 'Baraya',
#  'barbacoas': 'Barbacoas',
#  'barbosa': 'Barbosa',
#  'barichara': 'Barichara',
#  'barrancadeupia': 'Barranca de upia',
#  'barrancabermeja': 'Barrancabermeja',
#  'barrancas': 'Barrancas',
#  'barrancodeloba': 'Barranco de loba',
#  'barrancominas': 'Barranco minas',
#  'barranquilla': 'Barranquilla',
#  'barriosunidos': 'Barrios Unidos',
#  'becerril': 'Becerril',
#  'belalcazar': 'Belalcazar',
#  'belen': 'Belen',
#  'belendelosandaquies': 'Belen de los andaquies',
#  'matanza': 'Matanza',
#  'medellin': 'Medellin',
#  'medina': 'Medina',
#  'medioatrato': 'Medio atrato',
#  'mediobaudo': 'Medio baudo',
#  'melgar': 'Melgar',
#  'mercaderes': 'Mercaderes',
#  'mesetas': 'Mesetas',
#  'meta-departamento': 'Meta - DEPARTAMENTO',
#  'milan': 'Milan',
#  'mistrato': 'Mistrato',
#  'mitu': 'Mitu',
#  'mocoa': 'Mocoa',
#  'mogotes': 'Mogotes',
#  'molagavita': 'Molagavita',
#  'momil': 'Momil',
#  'mompos': 'Mompos',
#  'mongua': 'Mongua',
#  'mongui': 'Mongui',
#  'moniquira': 'Moniquira',
#  'miraflores': 'Miraflores',
#  'miranda': 'Miranda',
#  'miriti-parana': 'Miriti-parana',
#  'montebello': 'Montebello',
#  'montecristo': 'Montecristo',
#  'montelibano': 'Montelibano',
#  'montenegro': 'Montenegro',
#  'monteria': 'Monteria',
#  'monterrey': 'Monterrey',
#  'monitos': 'Moñitos',
#  'morales': 'Morales',
#  'morelia': 'Morelia',
#  'morichal(morichalnuevo)': 'Morichal (morichal nuevo)',
#  'morroa': 'Morroa',
#  'mosquera': 'Mosquera',
#  'motavita': 'Motavita',
#  'murillo': 'Murillo',
#  'murindo': 'Murindo',
#  'mutata': 'Mutata',
#  'mutiscua': 'Mutiscua',
#  'muzo': 'Muzo',
#  'narino': 'Nariño',
#  'nataga': 'Nataga',
#  'natagaima': 'Natagaima',
#  'nechi': 'Nechi',
#  'necocli': 'Necocli',
#  'neira': 'Neira',
#  'neiva': 'Neiva',
#  'nemocon': 'Nemocon',
#  'nilo': 'Nilo',
#  'nimaima': 'Nimaima',
#  'nobsa': 'Nobsa',
#  'nocaima': 'Nocaima',
#  'norcasia': 'Norcasia',
#  'novita': 'Novita',
#  'nuevocolon': 'Nuevo colon',
#  'nunchia': 'Nunchia',
#  'nuqui': 'Nuqui',
#  'obando': 'Obando',
#  'ocamonte': 'Ocamonte',
#  'ocana': 'Ocaña',
#  'oiba': 'Oiba',
#  'oicata': 'Oicata',
#  'olaya': 'Olaya',
#  'olayaherrera(bocasdesatinga)': 'Olaya herrera (bocas de satinga)',
#  'onzaga': 'Onzaga',
#  'oporapa': 'Oporapa',
#  'orito': 'Orito',
#  'orocue': 'Orocue',
#  'ortega': 'Ortega',
#  'ospina': 'Ospina',
#  'otanche': 'Otanche',
#  'otromunicipio': 'Otro municipio',
#  'pacora': 'Pacora',
#  'padilla': 'Padilla',
#  'paez': 'Paez',
#  'paez(belalcazar)': 'Paez (belalcazar)',
#  'paicol': 'Paicol',
#  'pailitas': 'Pailitas',
#  'paime': 'Paime',
#  'paipa': 'Paipa',
#  'pajarito': 'Pajarito',
#  'palermo': 'Palermo',
#  'palestina': 'Palestina',
#  'palmar': 'Palmar',
#  'palmardevarela': 'Palmar de varela',
#  'palmasdelsocorro': 'Palmas del socorro',
#  'palmira': 'Palmira',
#  'palmito': 'Palmito',
#  'palocabildo': 'Palocabildo',
#  'pamplona': 'Pamplona',
#  'pamplonita': 'Pamplonita',
#  'panapana(campoalegre)': 'Pana pana (campo alegre)',
#  'pandi': 'Pandi',
#  'panqueba': 'Panqueba',
#  'papunaua(morichal)': 'Papunaua (morichal)',
#  'paramo': 'Paramo',
#  'paratebueno': 'Paratebueno',
#  'pasca': 'Pasca',
#  'pasto(sanjuandepasto)': 'Pasto (san juan de pasto)',
#  'patia(elbordo)': 'Patia (el bordo)',
#  'pauna': 'Pauna',
#  'paya': 'Paya',
#  'pazdeariporo': 'Paz de ariporo',
#  'pazdelrio': 'Paz del rio',
#  'pedraza': 'Pedraza',
#  'pelaya': 'Pelaya',
#  'pensilvania': 'Pensilvania',
#  'penol': 'Peñol',
#  'peque': 'Peque',
#  'pereira': 'Pereira',
#  'pesca': 'Pesca',
#  'ovejas': 'Ovejas',
#  'pachavita': 'Pachavita',
#  'pacho': 'Pacho',
#  'pacoa': 'Pacoa',
#  'piamonte': 'Piamonte',
#  'piedecuesta': 'Piedecuesta',
#  'piedras': 'Piedras',
#  'piendamo': 'Piendamo',
#  'pijao': 'Pijao',
#  'pijinodelcarmen(pijino)': 'Pijiño del carmen (pijiño)',
#  'pinchote': 'Pinchote',
#  'pinillos': 'Pinillos',
#  'piojo': 'Piojo',
#  'pisba': 'Pisba',
#  'pital': 'Pital',
#  'pitalito': 'Pitalito',
#  'pivijay': 'Pivijay',
#  'planadas': 'Planadas',
#  'planetarica': 'Planeta rica',
#  'plato': 'Plato',
#  'policarpa': 'Policarpa',
#  'polonuevo': 'Polo nuevo',
#  'ponedera': 'Ponedera',
#  'popayan': 'Popayan',
#  'pore': 'Pore',
#  'potosi': 'Potosi',
#  'pradera': 'Pradera',
#  'prado': 'Prado',
#  'providencia': 'Providencia',
#  'pueblobello': 'Pueblo bello',
#  'pueblonuevo': 'Pueblo nuevo',
#  'pueblorico': 'Pueblo rico',
#  'pueblorrico': 'Pueblorrico',
#  'puebloviejo': 'Puebloviejo',
#  'puentearanda': 'Puente Aranda',
#  'puentenacional': 'Puente nacional',
#  'puerres': 'Puerres',
#  'puertoalegria': 'Puerto alegria',
#  'puertoarica': 'Puerto arica',
#  'puertoasis': 'Puerto asis',
#  'puertoberrio': 'Puerto berrio',
#  'puertoboyaca': 'Puerto boyaca',
#  'puertocaicedo': 'Puerto caicedo',
#  'puertocarreno': 'Puerto carreño',
#  'puertocolombia': 'Puerto colombia',
#  'puertoconcordia': 'Puerto concordia',
#  'puertoescondido': 'Puerto escondido',
#  'puertogaitan': 'Puerto gaitan',
#  'puertoguzman': 'Puerto guzman',
#  'puertoinirida': 'Puerto inirida',
#  'puertoleguizamo': 'Puerto leguizamo',
#  'puertolibertador': 'Puerto libertador',
#  'puertolleras': 'Puerto lleras',
#  'puertolopez': 'Puerto lopez',
#  'puertonare(lamagdalena)': 'Puerto nare (la magdalena)',
#  'puertonarino': 'Puerto nariño',
#  'puertoparra': 'Puerto parra',
#  'puertorico': 'Puerto rico',
#  'puertorondon': 'Puerto rondon',
#  'puertosalgar': 'Puerto salgar',
#  'puertosantander': 'Puerto santander',
#  'puertotejada': 'Puerto tejada',
#  'puertotriunfo': 'Puerto triunfo',
#  'puertowilches': 'Puerto wilches',
#  'puli': 'Puli',
#  'pupiales': 'Pupiales',
#  'purace(coconuco)': 'Purace (coconuco)',
#  'purificacion': 'Purificacion',
#  'purisima': 'Purisima',
#  'putumayo-departamento': 'Putumayo - DEPARTAMENTO',
#  'quebradanegra': 'Quebradanegra',
#  'quetame': 'Quetame',
#  'quibdo(sanfranciscodequibdo)': 'Quibdo (san francisco de quibdo)',
#  'quimbaya': 'Quimbaya',
#  'quinchia': 'Quinchia',
#  'quindio-departamento': 'Quindío - DEPARTAMENTO',
#  'quipama': 'Quipama',
#  'quipile': 'Quipile',
#  'rafaeluribe': 'Rafael Uribe',
#  'ragonvalia': 'Ragonvalia',
#  'ramiriqui': 'Ramiriqui',
#  'raquira': 'Raquira',
#  'recetor': 'Recetor',
#  'regidor': 'Regidor',
#  'remedios': 'Remedios',
#  'remolino': 'Remolino',
#  'repelon': 'Repelon',
#  'restrepo': 'Restrepo',
#  'retiro': 'Retiro',
#  'ricaurte': 'Ricaurte',
#  'riodeoro': 'Rio de oro',
#  'rioviejo': 'Rio viejo',
#  'rioblanco': 'Rioblanco',
#  'riofrio': 'Riofrio',
#  'riohacha': 'Riohacha',
#  'rionegro': 'Rionegro',
#  'rioquito': 'Rioquito',
#  'riosucio': 'Riosucio',
#  'risaralda': 'Risaralda',
#  'risaralda-departamento': 'Risaralda - DEPARTAMENTO',
#  'rivera': 'Rivera',
#  'robertopayan(sanjose)': 'Roberto payan (san jose)',
#  'roldanillo': 'Roldanillo',
#  'roncesvalles': 'Roncesvalles',
#  'rondon': 'Rondon',
#  'rosas': 'Rosas',
#  'rovira': 'Rovira',
#  'sabanadetorres': 'Sabana de torres',
#  'sabanagrande': 'Sabanagrande',
#  'sabanalarga': 'Sabanalarga',
#  'sabanasdesanangel': 'Sabanas de san angel',
#  'sabaneta': 'Sabaneta',
#  'saboya': 'Saboya',
#  'sacama': 'Sacama',
#  'sachica': 'Sachica',
#  'sahagun': 'Sahagun',
#  'saladoblanco': 'Saladoblanco',
#  'salamina': 'Salamina',
#  'salazar': 'Salazar',
#  'saldana': 'Saldaña',
#  'salento': 'Salento',
#  'salgar': 'Salgar',
#  'samaca': 'Samaca',
#  'samana': 'Samana',
#  'samaniego': 'Samaniego',
#  'sampues': 'Sampues',
#  'sanantoniodeltequendama': 'San  antonio del tequendama',
#  'sanjuandearama': 'San  juan de arama',
#  'sanvicentedelcaguan': 'San  vicente del caguan',
#  'sanagustin': 'San agustin',
#  'sanalberto': 'San alberto',
#  'sanandres': 'San andres',
#  'sanandressotavento': 'San andres sotavento',
#  'sanantero': 'San antero',
#  'sanantonio': 'San antonio',
#  'sanbenito': 'San benito',
#  'sanbenitoabad': 'San benito abad',
#  'sanbernardo': 'San bernardo',
#  'sanbernardodelviento': 'San bernardo del viento',
#  'sancalixto': 'San calixto',
#  'sancarlos': 'San carlos',
#  'sancarlosdeguaroa': 'San carlos de guaroa',
#  'sancayetano': 'San cayetano',
#  'sancristobal': 'San cristobal',
#  'sansebastian': 'San sebastian',
#  'sansebastiandebuenavista': 'San sebastian de buenavista',
#  'sanvicente': 'San vicente',
#  'sanvicentedechucuri': 'San vicente de chucuri',
#  'sanzenon': 'San zenon',
#  'sandona': 'Sandona',
#  'santaana': 'Santa ana',
#  'santabarbara': 'Santa barbara',
#  'santabarbara(iscuande)': 'Santa barbara (iscuande)',
#  'santacatalina': 'Santa catalina',
#  'santacruz(guachaves)': 'Santa cruz (guachaves)',
#  'santafe': 'Santa Fé',
#  'santahelenadelopon': 'Santa helena del opon',
#  'santaisabel': 'Santa isabel',
#  'santalucia': 'Santa lucia',
#  'santamaria': 'Santa maria',
#  'santamarta(distritoturistico,culturalehistoricodesantamarta)': 'Santa marta (distrito turistico, cultural e historicode santa marta)',
#  'santarita': 'Santa rita',
#  'sandiego': 'San diego',
#  'saneduardo': 'San eduardo',
#  'sanestanislao': 'San estanislao',
#  'sanfelipe': 'San felipe',
#  'sanfernando': 'San fernando',
#  'sanfrancisco': 'San francisco',
#  'sangil': 'San gil',
#  'sanjacinto': 'San jacinto',
#  'sanjacintodelcauca': 'San jacinto del cauca',
#  'sanjeronimo': 'San jeronimo',
#  'sanjoaquin': 'San joaquin',
#  'sanjose': 'San jose',
#  'sanjosedefragua': 'San jose de fragua',
#  'sanjosedelamontana': 'San jose de la montaña',
#  'sanjosedemiranda': 'San jose de miranda',
#  'sanjosedeocune': 'San jose de ocune',
#  'sanjosedepare': 'San jose de pare',
#  'sanjosedelguaviare': 'San jose del guaviare',
#  'sanjosedelpalmar': 'San jose del palmar',
#  'sanjuandebetulia': 'San juan de betulia',
#  'sanjuanderioseco': 'San juan de rioseco',
#  'sanjuandeuraba': 'San juan de uraba',
#  'sanjuandelcesar': 'San juan del cesar',
#  'sanjuannepomuceno': 'San juan nepomuceno',
#  'sanjuanito': 'San juanito',
#  'sanlorenzo': 'San lorenzo',
#  'sanluis': 'San luis',
#  'sanluisdecubarral': 'San luis de cubarral',
#  'sanluisdegaceno': 'San luis de gaceno',
#  'sanluisdepalenque': 'San luis de palenque',
#  'sanmarcos': 'San marcos',
#  'sanmartin': 'San martin',
#  'sanmartindeloba': 'San martin de loba',
#  'sanmateo': 'San mateo',
#  'sanmiguel': 'San miguel',
#  'sanmiguel(ladorada)': 'San miguel (la dorada)',
#  'sanmigueldesema': 'San miguel de sema',
#  'sanonofre': 'San onofre',
#  'sanpablo': 'San pablo',
#  'sanpablodeborbur': 'San pablo de borbur',
#  'sanpedro': 'San pedro',
#  'sanpedrodecartago': 'San pedro de cartago',
#  'sanpedrodeuraba': 'San pedro de uraba',
#  'sanpelayo': 'San pelayo',
#  'sanrafael': 'San rafael',
#  'sanroque': 'San roque',
#  'santarosa': 'Santa rosa',
#  'santarosadecabal': 'Santa rosa de cabal',
#  'santarosadeosos': 'Santa rosa de osos',
#  'santarosadeviterbo': 'Santa rosa de viterbo',
#  'santarosadelsur': 'Santa rosa del sur',
#  'santarosalia': 'Santa rosalia',
#  'santasofia': 'Santa sofia',
#  'santana': 'Santana',
#  'santander-departamento': 'Santander - DEPARTAMENTO',
#  'santanderdequilichao': 'Santander de quilichao',
#  'santiago': 'Santiago',
#  'santodomingo': 'Santo domingo',
#  'santotomas': 'Santo tomas',
#  'santuario': 'Santuario',
#  'sapuyes': 'Sapuyes',
#  'saravena': 'Saravena',
#  'sardinata': 'Sardinata',
#  'sasaima': 'Sasaima',
#  'sativanorte': 'Sativanorte',
#  'sativasur': 'Sativasur',
#  'segovia': 'Segovia',
#  'sesquile': 'Sesquile',
#  'sevilla': 'Sevilla',
#  'siachoque': 'Siachoque',
#  'sibate': 'Sibate',
#  'sibundoy': 'Sibundoy',
#  'silos': 'Silos',
#  'silvania': 'Silvania',
#  'silvia': 'Silvia',
#  'simacota': 'Simacota',
#  'simijaca': 'Simijaca',
#  'simiti': 'Simiti',
#  'timbiqui': 'Timbiqui',
#  'tinjaca': 'Tinjaca',
#  'tipacoque': 'Tipacoque',
#  'tiquisio(puertorico)': 'Tiquisio (puerto rico)',
#  'titiribi': 'Titiribi',
#  'toca': 'Toca',
#  'tocaima': 'Tocaima',
#  'tocancipa': 'Tocancipa',
#  'togui': 'Togui',
#  'toledo': 'Toledo',
#  'tolu': 'Tolu',
#  'toluviejo': 'Toluviejo',
#  'tona': 'Tona',
#  'topaga': 'Topaga',
#  'since': 'Since',
#  'sincelejo': 'Sincelejo',
#  'sipi': 'Sipi',
#  'sitionuevo': 'Sitionuevo',
#  'soacha': 'Soacha',
#  'soata': 'Soata',
#  'socha': 'Socha',
#  'socorro': 'Socorro',
#  'socota': 'Socota',
#  'sogamoso': 'Sogamoso',
#  'solano': 'Solano',
#  'soledad': 'Soledad',
#  'solita': 'Solita',
#  'somondoco': 'Somondoco',
#  'sonson': 'Sonson',
#  'sopetran': 'Sopetran',
#  'soplaviento': 'Soplaviento',
#  'sopo': 'Sopo',
#  'sora': 'Sora',
#  'soraca': 'Soraca',
#  'sotaquira': 'Sotaquira',
#  'sotara(paispamba)': 'Sotara (paispamba)',
#  'suaita': 'Suaita',
#  'suan': 'Suan',
#  'suarez': 'Suarez',
#  'suaza': 'Suaza',
#  'suba': 'Suba',
#  'subachoque': 'Subachoque',
#  'sucre': 'Sucre',
#  'suesca': 'Suesca',
#  'sumapaz': 'Sumapaz',
#  'supata': 'Supata',
#  'supia': 'Supia',
#  'surata': 'Surata',
#  'susa': 'Susa',
#  'susacon': 'Susacon',
#  'sutamarchan': 'Sutamarchan',
#  'sutatausa': 'Sutatausa',
#  'sutatenza': 'Sutatenza',
#  'tabio': 'Tabio',
#  'tado': 'Tado',
#  'talaiguanuevo': 'Talaigua nuevo',
#  'tamalameque': 'Tamalameque',
#  'tamara': 'Tamara',
#  'tame': 'Tame',
#  'tamesis': 'Tamesis',
#  'taminango': 'Taminango',
#  'tangua': 'Tangua',
#  'taraira': 'Taraira',
#  'tarapaca': 'Tarapaca',
#  'taraza': 'Taraza',
#  'tarqui': 'Tarqui',
#  'tarso': 'Tarso',
#  'tasco': 'Tasco',
#  'tauramena': 'Tauramena',
#  'tausa': 'Tausa',
#  'tello': 'Tello',
#  'tena': 'Tena',
#  'tenerife': 'Tenerife',
#  'tenjo': 'Tenjo',
#  'tenza': 'Tenza',
#  'teorama': 'Teorama',
#  'teruel': 'Teruel',
#  'tesalia': 'Tesalia',
#  'teusaquillo': 'Teusaquillo',
#  'tibacuy': 'Tibacuy',
#  'tibana': 'Tibana',
#  'tibasosa': 'Tibasosa',
#  'tibirita': 'Tibirita',
#  'tibu': 'Tibu',
#  'tierralta': 'Tierralta',
#  'timana': 'Timana',
#  'timbio': 'Timbio',
#  'topaipi': 'Topaipi',
#  'toribio': 'Toribio',
#  'toro': 'Toro',
#  'tota': 'Tota',
#  'totoro': 'Totoro',
#  'trinidad': 'Trinidad',
#  'trujillo': 'Trujillo',
#  'tubara': 'Tubara',
#  'tulua': 'Tulua',
#  'tumaco': 'Tumaco',
#  'tunja': 'Tunja',
#  'tunjuelito': 'Tunjuelito',
#  'tunungua': 'Tunungua',
#  'tuquerres': 'Tuquerres',
#  'turbaco': 'Turbaco',
#  'turbana': 'Turbana',
#  'turbo': 'Turbo',
#  'turmeque': 'Turmeque',
#  'tuta': 'Tuta',
#  'tutasa': 'Tutasa',
#  'ubala': 'Ubala',
#  'ubaque': 'Ubaque',
#  'ubate': 'Ubate',
#  'ulloa': 'Ulloa',
#  'umbita': 'Umbita',
#  'une': 'Une',
#  'unguia': 'Unguia',
#  'unionpanamericana': 'Union panamericana',
#  'uramita': 'Uramita',
#  'uribia': 'Uribia',
#  'urrao': 'Urrao',
#  ...}

# %%
#Creo una nueva columna que se llame 'municipio_convertido' en el df_migrar. Básicamente, vamos a crear una clave
# a partir de mínusculas, con la cual se pueda generar coincidencias con el diccionario de municipio.

df_migrar['municipio_convertido'] = df_migrar["ciudad_asegurado"].str.replace(" ","").str.lower()

#Garantizo que el campo corresponda a sólo valores texto, y reemplazo los caracteres con tildes
df_migrar['municipio_convertido'] = df_migrar['municipio_convertido'].astype(str)
#Quito tildes y acentos de las minúsculas.
df_migrar['municipio_convertido'] = df_migrar['municipio_convertido'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')
df_migrar['municipio_convertido']
# Out:
# 0       quibdo
# 1       quibdo
# 2       quibdo
# 3       quibdo
# 4       quibdo
#         ...
# 496        nan
# 497        nan
# 498        nan
# 499        nan
# 500    lebrija
# Name: municipio_convertido, Length: 1709, dtype: object

# %%
#Revisamos cuales municipios no coinciden con el diccionario de municipios, con el fin de complementar el diccionario.
municipios_df_migrar = list(np.array(df_migrar['municipio_convertido']))
municipios_clave = list(np.array(municipio['clave_minuscula']))
municipios_ok = np.intersect1d(municipios_clave, municipios_df_migrar)
municipios_no_ok = np.setdiff1d(municipios_df_migrar, municipios_ok)
municipios_no_ok
# Out:
# array(['andagoya', 'arboleda', 'bogota', 'boraudo', 'cali', 'donajosefa',
#        'guachene', 'isnos', 'mallama', 'pasto', 'patia', 'purace',
#        'qubdo', 'quibdo', 'quindio', 'sanandresdetumaco',
#        'sanjosedelfragua', 'santamarta'], dtype='<U20')

# %%
#creo un diccionario que complemente a dic_municipio con los valores que no se pudieron hacer coincidir.
dic_municipios_definitivos = {'andagoya':'Revisar', 'arboleda':'Arboleda (berruecos)', 'bogota':'Bogotá D.C.', 'boraudo':'Revisar',
                              'cali':'Cali (santiago de cali)', 'donajosefa':'Revisar', 'guachene':'Revisar', 'isnos':'Isnos (san jose de isnos)',
                              'mallama':'Mallama (piedrancha)', 'pasto':'Pasto (san juan de pasto)',
                              'patia':'Patia (el bordo)','purace':'Purace (coconuco)','qubdo':'Quibdo (san francisco de quibdo)', 
                              'quibdo':'Quibdo (san francisco de quibdo)', 'quindio':'Revisar', 'sanandresdetumaco':'Tumaco',
                              'sanjosedelfragua':'San jose de fragua', 'santamarta':'Santa marta (distrito turistico, cultural e historicode santa marta)'}
dic_municipios_definitivos.update(dic_municipios)

# %%
#genero el diccionario definitivo
dic_municipios_definitivos
# Out:
# {'andagoya': 'Revisar',
#  'arboleda': 'Arboleda (berruecos)',
#  'bogota': 'Bogotá D.C.',
#  'boraudo': 'Revisar',
#  'cali': 'Cali (santiago de cali)',
#  'donajosefa': 'Revisar',
#  'guachene': 'Revisar',
#  'isnos': 'Isnos (san jose de isnos)',
#  'mallama': 'Mallama (piedrancha)',
#  'pasto': 'Pasto (san juan de pasto)',
#  'patia': 'Patia (el bordo)',
#  'purace': 'Purace (coconuco)',
#  'qubdo': 'Quibdo (san francisco de quibdo)',
#  'quibdo': 'Quibdo (san francisco de quibdo)',
#  'quindio': 'Revisar',
#  'sanandresdetumaco': 'Tumaco',
#  'sanjosedelfragua': 'San jose de fragua',
#  'santamarta': 'Santa marta (distrito turistico, cultural e historicode santa marta)',
#  'belendeumbria': 'Belen de umbria',
#  'bello': 'Bello',
#  'belmira': 'Belmira',
#  'beltran': 'Beltran',
#  'berbeo': 'Berbeo',
#  'betania': 'Betania',
#  'beteitiva': 'Beteitiva',
#  'betulia': 'Betulia',
#  'bituima': 'Bituima',
#  'boavita': 'Boavita',
#  'bochalema': 'Bochalema',
#  'bogotad.c.': 'Bogotá D.C.',
#  'bojaca': 'Bojaca',
#  'bojaya(bellavista)': 'Bojaya (bellavista)',
#  'bolivar': 'Bolivar',
#  'bosa': 'Bosa',
#  'bosconia': 'Bosconia',
#  'boyaca': 'Boyaca',
#  'boyaca-departamento': 'Boyacá - DEPARTAMENTO',
#  'briceno': 'Briceño',
#  'bucaramanga': 'Bucaramanga',
#  'bucarasica': 'Bucarasica',
#  'buenaventura': 'Buenaventura',
#  'buenavista': 'Buenavista',
#  'buenosaires': 'Buenos aires',
#  'buesaco': 'Buesaco',
#  'buga': 'Buga',
#  'bugalagrande': 'Bugalagrande',
#  'buritica': 'Buritica',
#  'busbanza': 'Busbanza',
#  'cabrera': 'Cabrera',
#  'cabuyaro': 'Cabuyaro',
#  'cacahual': 'Cacahual',
#  'caceres': 'Caceres',
#  'cachipay': 'Cachipay',
#  'cachira': 'Cachira',
#  'cacota': 'Cacota',
#  'caicedo': 'Caicedo',
#  'caicedonia': 'Caicedonia',
#  'caimito': 'Caimito',
#  'cajamarca': 'Cajamarca',
#  'cajibio': 'Cajibio',
#  'cajica': 'Cajica',
#  'calamar': 'Calamar',
#  'calarca': 'Calarca',
#  'caldas': 'Caldas',
#  'caldas-departamento': 'Caldas - DEPARTAMENTO',
#  'caldono': 'Caldono',
#  'cali(santiagodecali)': 'Cali (santiago de cali)',
#  'california': 'California',
#  'calima(darien)': 'Calima (darien)',
#  'caloto': 'Caloto',
#  'campamento': 'Campamento',
#  'campodelacruz': 'Campo de la cruz',
#  'campoalegre': 'Campoalegre',
#  'campohermoso': 'Campohermoso',
#  'canalete': 'Canalete',
#  'candelaria': 'Candelaria',
#  'cantagallo': 'Cantagallo',
#  'cantondesanpablo(managru)': 'Canton de san pablo (managru)',
#  'canasgordas': 'Cañasgordas',
#  'caparrapi': 'Caparrapi',
#  'capitanejo': 'Capitanejo',
#  'caqueza': 'Caqueza',
#  'caracoli': 'Caracoli',
#  'caramanta': 'Caramanta',
#  'carcasi': 'Carcasi',
#  'carepa': 'Carepa',
#  'carmenapicala': 'Carmen apicala',
#  'carmendecarupa': 'Carmen de carupa',
#  'carmendeviboral': 'Carmen de viboral',
#  'carolina': 'Carolina',
#  'cartagena': 'Cartagena',
#  'cartagenadelchaira': 'Cartagena del chaira',
#  'cartago': 'Cartago',
#  'caruru': 'Caruru',
#  'casabianca': 'Casabianca',
#  'casanare-departamento': 'Casanare - DEPARTAMENTO',
#  'castillalanueva': 'Castilla la nueva',
#  'cauca-departamento': 'Cauca - DEPARTAMENTO',
#  'caucasia': 'Caucasia',
#  'cepita': 'Cepita',
#  'cerete': 'Cerete',
#  'cerinza': 'Cerinza',
#  'cerrito': 'Cerrito',
#  'cerrosanantonio': 'Cerro san antonio',
#  'cesar-departamento': 'Cesar - DEPARTAMENTO',
#  'chachagui': 'Chachagui',
#  'chaguani': 'Chaguani',
#  'chalan': 'Chalan',
#  'chameza': 'Chameza',
#  'chaparral': 'Chaparral',
#  'chapinero': 'Chapinero',
#  'charala': 'Charala',
#  'charta': 'Charta',
#  'chia': 'Chia',
#  'chigorodo': 'Chigorodo',
#  'chima': 'Chima',
#  'chimichagua': 'Chimichagua',
#  'chinacota': 'Chinacota',
#  'chinavita': 'Chinavita',
#  'chinchina': 'Chinchina',
#  'chinu': 'Chinu',
#  'chipaque': 'Chipaque',
#  'chipata': 'Chipata',
#  'chiquinquira': 'Chiquinquira',
#  'chiquiza': 'Chiquiza',
#  'chiriguana': 'Chiriguana',
#  'chiscas': 'Chiscas',
#  'chita': 'Chita',
#  'chitaga': 'Chitaga',
#  'chitaraque': 'Chitaraque',
#  'chivata': 'Chivata',
#  'chivolo': 'Chivolo',
#  'chivor': 'Chivor',
#  'choachi': 'Choachi',
#  'choconta': 'Choconta',
#  'cicuco': 'Cicuco',
#  'cienaga': 'Cienaga',
#  'cienagadeoro': 'Cienaga de oro',
#  'cienega': 'Cienega',
#  'cimitarra': 'Cimitarra',
#  'circasia': 'Circasia',
#  'cisneros': 'Cisneros',
#  'ciudadbolivar': 'Ciudad Bolivar',
#  'clemencia': 'Clemencia',
#  'cocorna': 'Cocorna',
#  'coello': 'Coello',
#  'cogua': 'Cogua',
#  'colombia': 'Colombia',
#  'colon': 'Colon',
#  'colon(genova)': 'Colon (genova)',
#  'coloso(ricaurte)': 'Coloso (ricaurte)',
#  'combita': 'Combita',
#  'concepcion': 'Concepcion',
#  'concordia': 'Concordia',
#  'condoto': 'Condoto',
#  'confines': 'Confines',
#  'consaca': 'Consaca',
#  'contadero': 'Contadero',
#  'contratacion': 'Contratacion',
#  'convencion': 'Convencion',
#  'copacabana': 'Copacabana',
#  'coper': 'Coper',
#  'cordoba': 'Cordoba',
#  'corinto': 'Corinto',
#  'coromoro': 'Coromoro',
#  'corozal': 'Corozal',
#  'corrales': 'Corrales',
#  'cota': 'Cota',
#  'cotorra': 'Cotorra',
#  'covarachia': 'Covarachia',
#  'coyaima': 'Coyaima',
#  'cravonorte': 'Cravo norte',
#  'cuaspud(carlosama)': 'Cuaspud (carlosama)',
#  'cubara': 'Cubara',
#  'cucaita': 'Cucaita',
#  'cucunuba': 'Cucunuba',
#  'cucuta': 'Cucuta',
#  'cucutilla': 'Cucutilla',
#  'cuitiva': 'Cuitiva',
#  'cumaral': 'Cumaral',
#  'cumaribo': 'Cumaribo',
#  'cumbal': 'Cumbal',
#  'cumbitara': 'Cumbitara',
#  'cunday': 'Cunday',
#  'curillo': 'Curillo',
#  'curiti': 'Curiti',
#  'curumani': 'Curumani',
#  'dabeiba': 'Dabeiba',
#  'dagua': 'Dagua',
#  'dibulla': 'Dibulla',
#  'distraccion': 'Distraccion',
#  'dolores': 'Dolores',
#  'donmatias': 'Don matias',
#  'dosquebradas': 'Dos quebradas',
#  'duitama': 'Duitama',
#  'durania': 'Durania',
#  'ebejico': 'Ebejico',
#  'elaguila': 'El aguila',
#  'elbagre': 'El bagre',
#  'elbanco': 'El banco',
#  'elcairo': 'El cairo',
#  'elcalvario': 'El calvario',
#  'elcarmen': 'El carmen',
#  'elcarmendeatrato': 'El carmen de atrato',
#  'elcarmendebolivar': 'El carmen de bolivar',
#  'elcarmendechucury': 'El carmen de chucury',
#  'elcastillo': 'El castillo',
#  'elcerrito': 'El cerrito',
#  'elcharco': 'El charco',
#  'elcocuy': 'El cocuy',
#  'elcolegio': 'El colegio',
#  'elcopey': 'El copey',
#  'eldoncello': 'El doncello',
#  'eldorado': 'El dorado',
#  'eldovio': 'El dovio',
#  'elencanto': 'El encanto',
#  'elespino': 'El espino',
#  'elguacamayo': 'El guacamayo',
#  'elguamo': 'El guamo',
#  'elmolino': 'El molino',
#  'elpaso': 'El paso',
#  'elpaujil': 'El paujil',
#  'elpenol': 'El peñol',
#  'elpenon': 'El peñon',
#  'elpinon': 'El piñon',
#  'elplayon': 'El playon',
#  'elreten': 'El reten',
#  'elretorno': 'El retorno',
#  'elrosal': 'El rosal',
#  'elrosario': 'El rosario',
#  'eltablon': 'El tablon',
#  'eltambo': 'EL TAMBO',
#  'eltarra': 'El tarra',
#  'elzulia': 'El zulia',
#  'elias': 'Elias',
#  'encino': 'Encino',
#  'enciso': 'Enciso',
#  'engativa': 'Engativa',
#  'entrerrios': 'Entrerrios',
#  'envigado': 'Envigado',
#  'espinal': 'Espinal',
#  'facatativa': 'Facatativa',
#  'falan': 'Falan',
#  'filadelfia': 'Filadelfia',
#  'filandia': 'Filandia',
#  'firavitoba': 'Firavitoba',
#  'flandes': 'Flandes',
#  'florencia': 'Florencia',
#  'floresta': 'Floresta',
#  'florian': 'Florian',
#  'florida': 'Florida',
#  'floridablanca': 'Floridablanca',
#  'fomeque': 'Fomeque',
#  'fonseca': 'Fonseca',
#  'fontibon': 'Fontibon',
#  'fortul': 'Fortul',
#  'fosca': 'Fosca',
#  'franciscopizarro(salahonda)': 'Francisco pizarro (salahonda)',
#  'fredonia': 'Fredonia',
#  'fresno': 'Fresno',
#  'frontino': 'Frontino',
#  'fuentedeoro': 'Fuente de oro',
#  'fundacion': 'Fundacion',
#  'funes': 'Funes',
#  'funza': 'Funza',
#  'fuquene': 'Fuquene',
#  'fusagasuga': 'Fusagasuga',
#  'gachala': 'Gachala',
#  'gachancipa': 'Gachancipa',
#  'gachantiva': 'Gachantiva',
#  'gacheta': 'Gacheta',
#  'galan': 'Galan',
#  'galapa': 'Galapa',
#  'galeras(nuevagranada)': 'Galeras (nueva granada)',
#  'gama': 'Gama',
#  'gamarra': 'Gamarra',
#  'gambita': 'Gambita',
#  'gameza': 'Gameza',
#  'garagoa': 'Garagoa',
#  'garzon': 'Garzon',
#  'genova': 'Genova',
#  'gigante': 'Gigante',
#  'ginebra': 'Ginebra',
#  'giraldo': 'Giraldo',
#  'girardot': 'Girardot',
#  'girardota': 'Girardota',
#  'giron': 'Giron',
#  'gomezplata': 'Gomez plata',
#  'gonzalez': 'Gonzalez',
#  'gramalote': 'Gramalote',
#  'granada': 'Granada',
#  'guaca': 'Guaca',
#  'guacamayas': 'Guacamayas',
#  'guacari': 'Guacari',
#  'guacheta': 'Guacheta',
#  'guachucal': 'Guachucal',
#  'guadalupe': 'Guadalupe',
#  'guaduas': 'Guaduas',
#  'guaitarilla': 'Guaitarilla',
#  'gualmatan': 'Gualmatan',
#  'guamal': 'Guamal',
#  'guamo': 'Guamo',
#  'guapi': 'Guapi',
#  'guapota': 'Guapota',
#  'guaranda': 'Guaranda',
#  'guarne': 'Guarne',
#  'guasca': 'Guasca',
#  'guatape': 'Guatape',
#  'guataqui': 'Guataqui',
#  'guatavita': 'Guatavita',
#  'guateque': 'Guateque',
#  'guatica': 'Guatica',
#  'guavata': 'Guavata',
#  'guayabaldesiquima': 'Guayabal de siquima',
#  'guayabetal': 'Guayabetal',
#  'guayata': 'Guayata',
#  'guepsa': 'Guepsa',
#  'guican': 'Guican',
#  'gutierrez': 'Gutierrez',
#  'hacari': 'Hacari',
#  'hatillodeloba': 'Hatillo de loba',
#  'hato': 'Hato',
#  'hatocorozal': 'Hato corozal',
#  'hatonuevo': 'Hatonuevo',
#  'heliconia': 'Heliconia',
#  'herran': 'Herran',
#  'herveo': 'Herveo',
#  'hispania': 'Hispania',
#  'hobo': 'Hobo',
#  'honda': 'Honda',
#  'huila-departamento': 'Huila - DEPARTAMENTO',
#  'ibague': 'Ibague',
#  'icononzo': 'Icononzo',
#  'iles': 'Iles',
#  'imues': 'Imues',
#  'inza': 'Inza',
#  'ipiales': 'Ipiales',
#  'iquira': 'Iquira',
#  'isnos(sanjosedeisnos)': 'Isnos (san jose de isnos)',
#  'istmina': 'Istmina',
#  'itagui': 'Itagui',
#  'ituango': 'Ituango',
#  'iza': 'Iza',
#  'jambalo': 'Jambalo',
#  'jamundi': 'Jamundi',
#  'jardin': 'Jardin',
#  'jenesano': 'Jenesano',
#  'jerico': 'Jerico',
#  'jerusalen': 'Jerusalen',
#  'jesusmaria': 'Jesus maria',
#  'jordan': 'Jordan',
#  'juandeacosta': 'Juan de acosta',
#  'junin': 'Junin',
#  'jurado': 'Jurado',
#  'kennedy': 'Kennedy',
#  'laapartada': 'La apartada',
#  'laargentina': 'La argentina',
#  'labelleza': 'La belleza',
#  'lacalera': 'La calera',
#  'lacapilla': 'La capilla',
#  'laceja': 'La ceja',
#  'lacelia': 'La celia',
#  'lachorrera': 'La chorrera',
#  'lacruz': 'La cruz',
#  'lacumbre': 'La cumbre',
#  'ladorada': 'La dorada',
#  'laesperanza': 'La esperanza',
#  'laestrella': 'La estrella',
#  'laflorida': 'La florida',
#  'lagloria': 'La gloria',
#  'laguadalupe': 'La guadalupe',
#  'laguajira-departamento': 'La Guajira - DEPARTAMENTO',
#  'lahormiga(valledelguamuez)': 'La hormiga (valle del guamuez)',
#  'lajaguadelpilar': 'La jagua del pilar',
#  'lajaguaibirico': 'La jagua ibirico',
#  'lallanada': 'La llanada',
#  'lamacarena': 'La macarena',
#  'lamerced': 'La merced',
#  'lamesa': 'La mesa',
#  'lamontanita': 'La montañita',
#  'lapalma': 'La palma',
#  'lapaz': 'La paz',
#  'lapaz(robles)': 'La paz (robles)',
#  'lapedrera': 'La pedrera',
#  'lapena': 'La peña',
#  'lapintada': 'La pintada',
#  'laplata': 'La plata',
#  'laplaya': 'La playa',
#  'laprimavera': 'La primavera',
#  'manaure(balcondelcesar)': 'Manaure (balcon del cesar)',
#  'mani': 'Mani',
#  'manizales': 'Manizales',
#  'manta': 'Manta',
#  'manzanares': 'Manzanares',
#  'mapiripan': 'Mapiripan',
#  'margarita': 'Margarita',
#  'marialabaja': 'Maria la baja',
#  'marinilla': 'Marinilla',
#  'maripi': 'Maripi',
#  'mariquita': 'Mariquita',
#  'marmato': 'Marmato',
#  'marquetalia': 'Marquetalia',
#  'marsella': 'Marsella',
#  'martires': 'Martires',
#  'marulanda': 'Marulanda',
#  'nan': nan,
#  'lasalina': 'La salina',
#  'lasierra': 'La sierra',
#  'latebaida': 'La tebaida',
#  'latola': 'La tola',
#  'launion': 'La union',
#  'lauribe': 'La uribe',
#  'lauvita': 'La uvita',
#  'lavega': 'La vega',
#  'lavictoria': 'La victoria',
#  'lavirginia': 'La virginia',
#  'labateca': 'Labateca',
#  'labranzagrande': 'Labranzagrande',
#  'landazuri': 'Landazuri',
#  'lebrija': 'Lebrija',
#  'leiva': 'Leiva',
#  'lejanias': 'Lejanias',
#  'lenguazaque': 'Lenguazaque',
#  'lerida': 'Lerida',
#  'leticia': 'Leticia',
#  'libano': 'Libano',
#  'liborina': 'Liborina',
#  'linares': 'Linares',
#  'litoraldelbajosanjuan(santagenovevadedocordo)': 'Litoral del bajo san juan (santa genoveva de docordo)',
#  'lloro': 'Lloro',
#  'lopez(micay)': 'Lopez (micay)',
#  'lorica': 'Lorica',
#  'losandes(sotomayor)': 'Los andes (sotomayor)',
#  'loscordobas': 'Los cordobas',
#  'lospalmitos': 'Los palmitos',
#  'lospatios': 'Los patios',
#  'lossantos': 'Los santos',
#  'lourdes': 'Lourdes',
#  'luruaco': 'Luruaco',
#  'macanal': 'Macanal',
#  'macaravita': 'Macaravita',
#  'maceo': 'Maceo',
#  'macheta': 'Macheta',
#  'madrid': 'Madrid',
#  'magangue': 'Magangue',
#  'magui(payan)': 'Magui (payan)',
#  'mahates': 'Mahates',
#  'maicao': 'Maicao',
#  'majagual': 'Majagual',
#  'malaga': 'Malaga',
#  'malambo': 'Malambo',
#  'mallama(piedrancha)': 'Mallama (piedrancha)',
#  'manati': 'Manati',
#  'manaure': 'Manaure',
#  '_': '_',
#  'abejorral': 'Abejorral',
#  'abrego': 'Abrego',
#  'abriaqui': 'Abriaqui',
#  'acacias': 'Acacias',
#  'acandi': 'Acandi',
#  'acevedo': 'Acevedo',
#  'achi': 'Achi',
#  'agrado': 'Agrado',
#  'aguadedios': 'Agua de dios',
#  'aguachica': 'Aguachica',
#  'aguada': 'Aguada',
#  'aguadas': 'Aguadas',
#  'aguazul': 'Aguazul',
#  'agustincodazzi': 'Agustin codazzi',
#  'aipe': 'Aipe',
#  'alban': 'Alban',
#  'alban(sanjose)': 'Alban (san jose)',
#  'albania': 'Albania',
#  'alcala': 'Alcala',
#  'aldana': 'Aldana',
#  'alejandria': 'Alejandria',
#  'algarrobo': 'Algarrobo',
#  'algeciras': 'Algeciras',
#  'almaguer': 'Almaguer',
#  'almeida': 'Almeida',
#  'alpujarra': 'Alpujarra',
#  'altamira': 'Altamira',
#  'altobaudo(piedepato)': 'Alto baudo (pie de pato)',
#  'altosdelrosario': 'Altos del rosario',
#  'alvarado': 'Alvarado',
#  'amaga': 'Amaga',
#  'amalfi': 'Amalfi',
#  'ambalema': 'Ambalema',
#  'anapoima': 'Anapoima',
#  'ancuya': 'Ancuya',
#  'andalucia': 'Andalucia',
#  'andes': 'Andes',
#  'angelopolis': 'Angelopolis',
#  'angostura': 'Angostura',
#  'anolaima': 'Anolaima',
#  'anori': 'Anori',
#  'anserma': 'Anserma',
#  'ansermanuevo': 'Ansermanuevo',
#  'antioquia': 'Antioquia',
#  'antonionarino': 'Antonio Nariño',
#  'anza': 'Anza',
#  'anzoategui': 'Anzoategui',
#  'apartado': 'Apartado',
#  'apia': 'Apia',
#  'apulo(rafaelreyes)': 'Apulo (rafael reyes)',
#  'aquitania': 'Aquitania',
#  'aracataca': 'Aracataca',
#  'aranzazu': 'Aranzazu',
#  'aratoca': 'Aratoca',
#  'arauca': 'Arauca',
#  'arauquita': 'Arauquita',
#  'arbelaez': 'Arbelaez',
#  'arboleda(berruecos)': 'Arboleda (berruecos)',
#  'arboledas': 'Arboledas',
#  'arboletes': 'Arboletes',
#  'arcabuco': 'Arcabuco',
#  'arenal': 'Arenal',
#  'argelia': 'Argelia',
#  'ariguani(eldificil)': 'Ariguani (el dificil)',
#  'arjona': 'Arjona',
#  'armenia': 'Armenia',
#  'armero(guayabal)': 'Armero (guayabal)',
#  'arroyohondo': 'Arroyohondo',
#  'astrea': 'Astrea',
#  'ataco': 'Ataco',
#  'atlantico': 'Atlántico',
#  'atrato': 'Atrato',
#  'ayapel': 'Ayapel',
#  'bagado': 'Bagado',
#  'bahiasolano(mutis)': 'Bahia solano (mutis)',
#  'bajobaudo(pizarro)': 'Bajo baudo (pizarro)',
#  'balboa': 'Balboa',
#  'baranoa': 'Baranoa',
#  'baraya': 'Baraya',
#  'barbacoas': 'Barbacoas',
#  'barbosa': 'Barbosa',
#  'barichara': 'Barichara',
#  'barrancadeupia': 'Barranca de upia',
#  'barrancabermeja': 'Barrancabermeja',
#  'barrancas': 'Barrancas',
#  'barrancodeloba': 'Barranco de loba',
#  'barrancominas': 'Barranco minas',
#  'barranquilla': 'Barranquilla',
#  'barriosunidos': 'Barrios Unidos',
#  'becerril': 'Becerril',
#  'belalcazar': 'Belalcazar',
#  'belen': 'Belen',
#  'belendelosandaquies': 'Belen de los andaquies',
#  'matanza': 'Matanza',
#  'medellin': 'Medellin',
#  'medina': 'Medina',
#  'medioatrato': 'Medio atrato',
#  'mediobaudo': 'Medio baudo',
#  'melgar': 'Melgar',
#  'mercaderes': 'Mercaderes',
#  'mesetas': 'Mesetas',
#  'meta-departamento': 'Meta - DEPARTAMENTO',
#  'milan': 'Milan',
#  'mistrato': 'Mistrato',
#  'mitu': 'Mitu',
#  'mocoa': 'Mocoa',
#  'mogotes': 'Mogotes',
#  'molagavita': 'Molagavita',
#  'momil': 'Momil',
#  'mompos': 'Mompos',
#  'mongua': 'Mongua',
#  'mongui': 'Mongui',
#  'moniquira': 'Moniquira',
#  'miraflores': 'Miraflores',
#  'miranda': 'Miranda',
#  'miriti-parana': 'Miriti-parana',
#  'montebello': 'Montebello',
#  'montecristo': 'Montecristo',
#  'montelibano': 'Montelibano',
#  'montenegro': 'Montenegro',
#  'monteria': 'Monteria',
#  'monterrey': 'Monterrey',
#  'monitos': 'Moñitos',
#  'morales': 'Morales',
#  'morelia': 'Morelia',
#  'morichal(morichalnuevo)': 'Morichal (morichal nuevo)',
#  'morroa': 'Morroa',
#  'mosquera': 'Mosquera',
#  'motavita': 'Motavita',
#  'murillo': 'Murillo',
#  'murindo': 'Murindo',
#  'mutata': 'Mutata',
#  'mutiscua': 'Mutiscua',
#  'muzo': 'Muzo',
#  'narino': 'Nariño',
#  'nataga': 'Nataga',
#  'natagaima': 'Natagaima',
#  'nechi': 'Nechi',
#  'necocli': 'Necocli',
#  'neira': 'Neira',
#  'neiva': 'Neiva',
#  'nemocon': 'Nemocon',
#  'nilo': 'Nilo',
#  'nimaima': 'Nimaima',
#  'nobsa': 'Nobsa',
#  'nocaima': 'Nocaima',
#  'norcasia': 'Norcasia',
#  'novita': 'Novita',
#  'nuevocolon': 'Nuevo colon',
#  'nunchia': 'Nunchia',
#  'nuqui': 'Nuqui',
#  'obando': 'Obando',
#  'ocamonte': 'Ocamonte',
#  'ocana': 'Ocaña',
#  'oiba': 'Oiba',
#  'oicata': 'Oicata',
#  'olaya': 'Olaya',
#  'olayaherrera(bocasdesatinga)': 'Olaya herrera (bocas de satinga)',
#  'onzaga': 'Onzaga',
#  'oporapa': 'Oporapa',
#  'orito': 'Orito',
#  'orocue': 'Orocue',
#  'ortega': 'Ortega',
#  'ospina': 'Ospina',
#  'otanche': 'Otanche',
#  'otromunicipio': 'Otro municipio',
#  'pacora': 'Pacora',
#  'padilla': 'Padilla',
#  'paez': 'Paez',
#  'paez(belalcazar)': 'Paez (belalcazar)',
#  'paicol': 'Paicol',
#  'pailitas': 'Pailitas',
#  'paime': 'Paime',
#  'paipa': 'Paipa',
#  'pajarito': 'Pajarito',
#  'palermo': 'Palermo',
#  'palestina': 'Palestina',
#  'palmar': 'Palmar',
#  'palmardevarela': 'Palmar de varela',
#  'palmasdelsocorro': 'Palmas del socorro',
#  'palmira': 'Palmira',
#  'palmito': 'Palmito',
#  'palocabildo': 'Palocabildo',
#  'pamplona': 'Pamplona',
#  'pamplonita': 'Pamplonita',
#  'panapana(campoalegre)': 'Pana pana (campo alegre)',
#  'pandi': 'Pandi',
#  'panqueba': 'Panqueba',
#  'papunaua(morichal)': 'Papunaua (morichal)',
#  'paramo': 'Paramo',
#  'paratebueno': 'Paratebueno',
#  'pasca': 'Pasca',
#  'pasto(sanjuandepasto)': 'Pasto (san juan de pasto)',
#  'patia(elbordo)': 'Patia (el bordo)',
#  'pauna': 'Pauna',
#  'paya': 'Paya',
#  'pazdeariporo': 'Paz de ariporo',
#  'pazdelrio': 'Paz del rio',
#  'pedraza': 'Pedraza',
#  'pelaya': 'Pelaya',
#  'pensilvania': 'Pensilvania',
#  'penol': 'Peñol',
#  'peque': 'Peque',
#  'pereira': 'Pereira',
#  'pesca': 'Pesca',
#  'ovejas': 'Ovejas',
#  'pachavita': 'Pachavita',
#  'pacho': 'Pacho',
#  'pacoa': 'Pacoa',
#  'piamonte': 'Piamonte',
#  'piedecuesta': 'Piedecuesta',
#  'piedras': 'Piedras',
#  'piendamo': 'Piendamo',
#  'pijao': 'Pijao',
#  'pijinodelcarmen(pijino)': 'Pijiño del carmen (pijiño)',
#  'pinchote': 'Pinchote',
#  'pinillos': 'Pinillos',
#  'piojo': 'Piojo',
#  'pisba': 'Pisba',
#  'pital': 'Pital',
#  'pitalito': 'Pitalito',
#  'pivijay': 'Pivijay',
#  'planadas': 'Planadas',
#  'planetarica': 'Planeta rica',
#  'plato': 'Plato',
#  'policarpa': 'Policarpa',
#  'polonuevo': 'Polo nuevo',
#  'ponedera': 'Ponedera',
#  'popayan': 'Popayan',
#  'pore': 'Pore',
#  'potosi': 'Potosi',
#  'pradera': 'Pradera',
#  'prado': 'Prado',
#  'providencia': 'Providencia',
#  'pueblobello': 'Pueblo bello',
#  'pueblonuevo': 'Pueblo nuevo',
#  'pueblorico': 'Pueblo rico',
#  'pueblorrico': 'Pueblorrico',
#  'puebloviejo': 'Puebloviejo',
#  'puentearanda': 'Puente Aranda',
#  'puentenacional': 'Puente nacional',
#  'puerres': 'Puerres',
#  'puertoalegria': 'Puerto alegria',
#  'puertoarica': 'Puerto arica',
#  'puertoasis': 'Puerto asis',
#  'puertoberrio': 'Puerto berrio',
#  'puertoboyaca': 'Puerto boyaca',
#  'puertocaicedo': 'Puerto caicedo',
#  'puertocarreno': 'Puerto carreño',
#  'puertocolombia': 'Puerto colombia',
#  'puertoconcordia': 'Puerto concordia',
#  'puertoescondido': 'Puerto escondido',
#  'puertogaitan': 'Puerto gaitan',
#  'puertoguzman': 'Puerto guzman',
#  'puertoinirida': 'Puerto inirida',
#  'puertoleguizamo': 'Puerto leguizamo',
#  'puertolibertador': 'Puerto libertador',
#  'puertolleras': 'Puerto lleras',
#  'puertolopez': 'Puerto lopez',
#  'puertonare(lamagdalena)': 'Puerto nare (la magdalena)',
#  'puertonarino': 'Puerto nariño',
#  'puertoparra': 'Puerto parra',
#  'puertorico': 'Puerto rico',
#  'puertorondon': 'Puerto rondon',
#  'puertosalgar': 'Puerto salgar',
#  'puertosantander': 'Puerto santander',
#  'puertotejada': 'Puerto tejada',
#  'puertotriunfo': 'Puerto triunfo',
#  'puertowilches': 'Puerto wilches',
#  'puli': 'Puli',
#  'pupiales': 'Pupiales',
#  'purace(coconuco)': 'Purace (coconuco)',
#  'purificacion': 'Purificacion',
#  'purisima': 'Purisima',
#  'putumayo-departamento': 'Putumayo - DEPARTAMENTO',
#  'quebradanegra': 'Quebradanegra',
#  'quetame': 'Quetame',
#  'quibdo(sanfranciscodequibdo)': 'Quibdo (san francisco de quibdo)',
#  'quimbaya': 'Quimbaya',
#  'quinchia': 'Quinchia',
#  'quindio-departamento': 'Quindío - DEPARTAMENTO',
#  'quipama': 'Quipama',
#  'quipile': 'Quipile',
#  'rafaeluribe': 'Rafael Uribe',
#  'ragonvalia': 'Ragonvalia',
#  'ramiriqui': 'Ramiriqui',
#  'raquira': 'Raquira',
#  'recetor': 'Recetor',
#  'regidor': 'Regidor',
#  'remedios': 'Remedios',
#  'remolino': 'Remolino',
#  'repelon': 'Repelon',
#  'restrepo': 'Restrepo',
#  'retiro': 'Retiro',
#  'ricaurte': 'Ricaurte',
#  'riodeoro': 'Rio de oro',
#  'rioviejo': 'Rio viejo',
#  'rioblanco': 'Rioblanco',
#  'riofrio': 'Riofrio',
#  'riohacha': 'Riohacha',
#  'rionegro': 'Rionegro',
#  'rioquito': 'Rioquito',
#  'riosucio': 'Riosucio',
#  'risaralda': 'Risaralda',
#  'risaralda-departamento': 'Risaralda - DEPARTAMENTO',
#  'rivera': 'Rivera',
#  'robertopayan(sanjose)': 'Roberto payan (san jose)',
#  'roldanillo': 'Roldanillo',
#  'roncesvalles': 'Roncesvalles',
#  'rondon': 'Rondon',
#  'rosas': 'Rosas',
#  'rovira': 'Rovira',
#  'sabanadetorres': 'Sabana de torres',
#  'sabanagrande': 'Sabanagrande',
#  'sabanalarga': 'Sabanalarga',
#  'sabanasdesanangel': 'Sabanas de san angel',
#  'sabaneta': 'Sabaneta',
#  'saboya': 'Saboya',
#  'sacama': 'Sacama',
#  'sachica': 'Sachica',
#  'sahagun': 'Sahagun',
#  'saladoblanco': 'Saladoblanco',
#  'salamina': 'Salamina',
#  'salazar': 'Salazar',
#  'saldana': 'Saldaña',
#  'salento': 'Salento',
#  'salgar': 'Salgar',
#  'samaca': 'Samaca',
#  'samana': 'Samana',
#  'samaniego': 'Samaniego',
#  'sampues': 'Sampues',
#  'sanantoniodeltequendama': 'San  antonio del tequendama',
#  'sanjuandearama': 'San  juan de arama',
#  'sanvicentedelcaguan': 'San  vicente del caguan',
#  'sanagustin': 'San agustin',
#  'sanalberto': 'San alberto',
#  'sanandres': 'San andres',
#  'sanandressotavento': 'San andres sotavento',
#  'sanantero': 'San antero',
#  'sanantonio': 'San antonio',
#  'sanbenito': 'San benito',
#  'sanbenitoabad': 'San benito abad',
#  'sanbernardo': 'San bernardo',
#  'sanbernardodelviento': 'San bernardo del viento',
#  'sancalixto': 'San calixto',
#  'sancarlos': 'San carlos',
#  'sancarlosdeguaroa': 'San carlos de guaroa',
#  'sancayetano': 'San cayetano',
#  'sancristobal': 'San cristobal',
#  'sansebastian': 'San sebastian',
#  'sansebastiandebuenavista': 'San sebastian de buenavista',
#  'sanvicente': 'San vicente',
#  'sanvicentedechucuri': 'San vicente de chucuri',
#  'sanzenon': 'San zenon',
#  'sandona': 'Sandona',
#  'santaana': 'Santa ana',
#  'santabarbara': 'Santa barbara',
#  'santabarbara(iscuande)': 'Santa barbara (iscuande)',
#  'santacatalina': 'Santa catalina',
#  'santacruz(guachaves)': 'Santa cruz (guachaves)',
#  'santafe': 'Santa Fé',
#  'santahelenadelopon': 'Santa helena del opon',
#  'santaisabel': 'Santa isabel',
#  'santalucia': 'Santa lucia',
#  'santamaria': 'Santa maria',
#  'santamarta(distritoturistico,culturalehistoricodesantamarta)': 'Santa marta (distrito turistico, cultural e historicode santa marta)',
#  'santarita': 'Santa rita',
#  'sandiego': 'San diego',
#  'saneduardo': 'San eduardo',
#  'sanestanislao': 'San estanislao',
#  'sanfelipe': 'San felipe',
#  'sanfernando': 'San fernando',
#  'sanfrancisco': 'San francisco',
#  'sangil': 'San gil',
#  'sanjacinto': 'San jacinto',
#  'sanjacintodelcauca': 'San jacinto del cauca',
#  'sanjeronimo': 'San jeronimo',
#  'sanjoaquin': 'San joaquin',
#  'sanjose': 'San jose',
#  'sanjosedefragua': 'San jose de fragua',
#  'sanjosedelamontana': 'San jose de la montaña',
#  'sanjosedemiranda': 'San jose de miranda',
#  'sanjosedeocune': 'San jose de ocune',
#  'sanjosedepare': 'San jose de pare',
#  'sanjosedelguaviare': 'San jose del guaviare',
#  'sanjosedelpalmar': 'San jose del palmar',
#  'sanjuandebetulia': 'San juan de betulia',
#  'sanjuanderioseco': 'San juan de rioseco',
#  'sanjuandeuraba': 'San juan de uraba',
#  'sanjuandelcesar': 'San juan del cesar',
#  'sanjuannepomuceno': 'San juan nepomuceno',
#  'sanjuanito': 'San juanito',
#  'sanlorenzo': 'San lorenzo',
#  'sanluis': 'San luis',
#  'sanluisdecubarral': 'San luis de cubarral',
#  'sanluisdegaceno': 'San luis de gaceno',
#  'sanluisdepalenque': 'San luis de palenque',
#  'sanmarcos': 'San marcos',
#  'sanmartin': 'San martin',
#  'sanmartindeloba': 'San martin de loba',
#  'sanmateo': 'San mateo',
#  'sanmiguel': 'San miguel',
#  'sanmiguel(ladorada)': 'San miguel (la dorada)',
#  'sanmigueldesema': 'San miguel de sema',
#  'sanonofre': 'San onofre',
#  'sanpablo': 'San pablo',
#  'sanpablodeborbur': 'San pablo de borbur',
#  'sanpedro': 'San pedro',
#  'sanpedrodecartago': 'San pedro de cartago',
#  'sanpedrodeuraba': 'San pedro de uraba',
#  'sanpelayo': 'San pelayo',
#  'sanrafael': 'San rafael',
#  'sanroque': 'San roque',
#  'santarosa': 'Santa rosa',
#  'santarosadecabal': 'Santa rosa de cabal',
#  'santarosadeosos': 'Santa rosa de osos',
#  'santarosadeviterbo': 'Santa rosa de viterbo',
#  'santarosadelsur': 'Santa rosa del sur',
#  'santarosalia': 'Santa rosalia',
#  'santasofia': 'Santa sofia',
#  'santana': 'Santana',
#  'santander-departamento': 'Santander - DEPARTAMENTO',
#  'santanderdequilichao': 'Santander de quilichao',
#  'santiago': 'Santiago',
#  'santodomingo': 'Santo domingo',
#  'santotomas': 'Santo tomas',
#  'santuario': 'Santuario',
#  'sapuyes': 'Sapuyes',
#  'saravena': 'Saravena',
#  'sardinata': 'Sardinata',
#  'sasaima': 'Sasaima',
#  'sativanorte': 'Sativanorte',
#  'sativasur': 'Sativasur',
#  'segovia': 'Segovia',
#  'sesquile': 'Sesquile',
#  'sevilla': 'Sevilla',
#  'siachoque': 'Siachoque',
#  'sibate': 'Sibate',
#  'sibundoy': 'Sibundoy',
#  'silos': 'Silos',
#  'silvania': 'Silvania',
#  'silvia': 'Silvia',
#  'simacota': 'Simacota',
#  'simijaca': 'Simijaca',
#  'simiti': 'Simiti',
#  'timbiqui': 'Timbiqui',
#  'tinjaca': 'Tinjaca',
#  'tipacoque': 'Tipacoque',
#  'tiquisio(puertorico)': 'Tiquisio (puerto rico)',
#  'titiribi': 'Titiribi',
#  'toca': 'Toca',
#  'tocaima': 'Tocaima',
#  'tocancipa': 'Tocancipa',
#  'togui': 'Togui',
#  'toledo': 'Toledo',
#  'tolu': 'Tolu',
#  'toluviejo': 'Toluviejo',
#  'tona': 'Tona',
#  'topaga': 'Topaga',
#  'since': 'Since',
#  'sincelejo': 'Sincelejo',
#  'sipi': 'Sipi',
#  'sitionuevo': 'Sitionuevo',
#  'soacha': 'Soacha',
#  'soata': 'Soata',
#  'socha': 'Socha',
#  'socorro': 'Socorro',
#  'socota': 'Socota',
#  'sogamoso': 'Sogamoso',
#  'solano': 'Solano',
#  'soledad': 'Soledad',
#  'solita': 'Solita',
#  'somondoco': 'Somondoco',
#  'sonson': 'Sonson',
#  'sopetran': 'Sopetran',
#  'soplaviento': 'Soplaviento',
#  'sopo': 'Sopo',
#  'sora': 'Sora',
#  'soraca': 'Soraca',
#  'sotaquira': 'Sotaquira',
#  'sotara(paispamba)': 'Sotara (paispamba)',
#  'suaita': 'Suaita',
#  'suan': 'Suan',
#  'suarez': 'Suarez',
#  'suaza': 'Suaza',
#  'suba': 'Suba',
#  'subachoque': 'Subachoque',
#  'sucre': 'Sucre',
#  'suesca': 'Suesca',
#  'sumapaz': 'Sumapaz',
#  'supata': 'Supata',
#  'supia': 'Supia',
#  'surata': 'Surata',
#  'susa': 'Susa',
#  'susacon': 'Susacon',
#  'sutamarchan': 'Sutamarchan',
#  'sutatausa': 'Sutatausa',
#  'sutatenza': 'Sutatenza',
#  'tabio': 'Tabio',
#  'tado': 'Tado',
#  'talaiguanuevo': 'Talaigua nuevo',
#  'tamalameque': 'Tamalameque',
#  'tamara': 'Tamara',
#  'tame': 'Tame',
#  'tamesis': 'Tamesis',
#  'taminango': 'Taminango',
#  'tangua': 'Tangua',
#  'taraira': 'Taraira',
#  'tarapaca': 'Tarapaca',
#  'taraza': 'Taraza',
#  'tarqui': 'Tarqui',
#  'tarso': 'Tarso',
#  'tasco': 'Tasco',
#  'tauramena': 'Tauramena',
#  'tausa': 'Tausa',
#  'tello': 'Tello',
#  'tena': 'Tena',
#  'tenerife': 'Tenerife',
#  'tenjo': 'Tenjo',
#  'tenza': 'Tenza',
#  'teorama': 'Teorama',
#  'teruel': 'Teruel',
#  'tesalia': 'Tesalia',
#  'teusaquillo': 'Teusaquillo',
#  'tibacuy': 'Tibacuy',
#  'tibana': 'Tibana',
#  'tibasosa': 'Tibasosa',
#  'tibirita': 'Tibirita',
#  'tibu': 'Tibu',
#  'tierralta': 'Tierralta',
#  'timana': 'Timana',
#  'timbio': 'Timbio',
#  'topaipi': 'Topaipi',
#  'toribio': 'Toribio',
#  'toro': 'Toro',
#  'tota': 'Tota',
#  'totoro': 'Totoro',
#  'trinidad': 'Trinidad',
#  'trujillo': 'Trujillo',
#  'tubara': 'Tubara',
#  'tulua': 'Tulua',
#  'tumaco': 'Tumaco',
#  'tunja': 'Tunja',
#  'tunjuelito': 'Tunjuelito',
#  'tunungua': 'Tunungua',
#  ...}

# %%
#Se reemplaza los valores que tiene ciudad_asegurado por los establecidos según el diccionario dic_municipios,
#tomando como clave el campo 'municipio_covertido' que se creó.
df_migrar['ciudad_asegurado'] = df_migrar['municipio_convertido'].map(dic_municipios_definitivos)

# %%
#Verifico que se haya re-escrito el nombre del municipio de manera correcta.
df_migrar['ciudad_asegurado'].value_counts()
# Out:
# Istmina                             137
# Cali (santiago de cali)              83
# Apartado                             71
# Puerto asis                          55
# Quibdo (san francisco de quibdo)     52
#                                    ...
# Silvania                              1
# Curillo                               1
# Granada                               1
# Antioquia                             1
# Colon                                 1
# Name: ciudad_asegurado, Length: 180, dtype: int64

# %% [markdown]
# el campo <b>ciudad_asegurado</b> se encuentra ajustado

# %%
#Exploro los valores únicos de 'producto_poliza', En este caso sólo hay un valor, y referencian vacios.
diccionario['producto_poliza']
# Out:
# array(['BANCO W', nan], dtype=object)

# %% [markdown]
# el campo <b>producto_poliza</b> se encuentra ajustado

# %%
#Empezamos a explorar los valores únicos de 'categoria_reclamacion', 
diccionario['categoria_reclamacion']
# Out:
# array(['MASIVO', 'NORMAL', 'ÚNICO', nan], dtype=object)

# %%
#Realizo un conteo de cada uno de los valores únicos.
df_migrar['categoria_reclamacion'].value_counts()
# Out:
# NORMAL    584
# MASIVO    507
# ÚNICO     192
# Name: categoria_reclamacion, dtype: int64

# %%
#Verifico el número de campos vacios, el cuál coincide con los vacios en producto.
df_migrar['categoria_reclamacion'].isna().sum()
# Out:
# 426

# %%
#Dado que ya hicimos la conversión, vamos a crear el feature item_categoria para cada registro, de
#tal manera que cree un identificador que se reinicia cada año, y está en fución de la categoría de reclamación.

df_migrar['cantidad_categoria'] = (df_migrar.groupby(['categoria_reclamacion','year'])['year'].cumcount()+1)
df_migrar['item_categoria'] = df_migrar['categoria_reclamacion'].str[:3] + "-" + df_migrar['cantidad_categoria'].astype(str)
df_migrar['item_categoria']
#resultado = df_migrar[['item_categoria', 'categoria_reclamacion','year']]
#resultado[['item_categoria', 'item_categoria_2','categoria_reclamacion','year']]
# Out:
# 0      MAS-1
# 1      MAS-2
# 2      MAS-3
# 3      MAS-4
# 4      MAS-5
#        ...
# 496      NaN
# 497      NaN
# 498      NaN
# 499      NaN
# 500      NaN
# Name: item_categoria, Length: 1709, dtype: object

# %% [markdown]
# el campo <b>categoria_reclamacion</b> fue ajustado

# %%
#Exploro los valores únicos de 'cobertura',
diccionario['cobertura']
# Out:
# array(['DAÑOS POR AGUA Y ANEGACIÓN', 'VIENTOS FUERTES',
#        'AVALANCHA Y DESLIZAMIENTO', 'NO COBERTURA', 'INCENDIO Y/O RAYO',
#        'HMCCP - AMIT', nan, 'CAIDA DE ARBOL', 'CHOQUE DE VEHÍCULO'],
#       dtype=object)

# %% [markdown]
# Todos los valores coinciden con la aplicación, exceptuando <b>'CHOQUE DE VEHÍCULO'</b>. Este valor se va a importar, pero
# no se podrá visualizar en la aplicación por lo cuál va a ser necesario modificarlo. Los valores núlos son los mismos registros ya identificados previamente en otros feature.

# %%
#Creo archivo de Excel para enviar a revisión.
mask = df_migrar['cobertura'] == 'CHOQUE DE VEHÍCULO'
df_migrar[mask].to_excel('verificar_cobertura.xlsx')

# %% [markdown]
# el campo <b>cobertura</b> fue ajustado

# %%
#Exploro los valores únicos de 'bienes'.
diccionario['bienes']
# Out:
# array(['CONTENIDOS', 'EDIFICIO Y CONTENIDOS', 'EDIFICIO', nan],
#       dtype=object)

# %% [markdown]
# En este caso, no es necesario hacer tratamiento pues corresponde a los valores estándar de la aplicación.

# %%
#Explor los valores únicos de 'estado'
diccionario['estado']
# Out:
# array(['PAGADO', 'OBJETADO', 'DESISTIDO', 'CERRADO', 'EN PROCESO', nan],
#       dtype=object)

# %% [markdown]
# Todos los valores que genera se encuentran listados en la aplicación, pero no <b>"CERRADO"</b>, por lo cuál vamos a crear un archivo de excel para su verificación manual.

# %%
mask = df_migrar['estado'] == 'CERRADO'
df_migrar[mask].to_excel('verificar_estado.xlsx')

#Se encuentran 7 casos en cerrado, sin embargo ese atributo no se encuentra en la aplicación.

# %% [markdown]
# el campo <b>estado</b> fue ajustado

# %%
#Exploro los valores únicos de 'observacion_1'
diccionario['observacion_1']
# Out:
# array(['PAGADO', 'OBJETADO- No. Guía 1144351764',
#        'OBJETADO- No. Guía 1145240418', 'OBJETADO- No. Guía 1144351763',
#        'OBJETADO- No. Guía 1144351753', 'OBJETADO- No. Guía 1144351745',
#        'OBJETADO- No. Guía 1144351752', 'OBJETADO- No. Guía 1144351749',
#        'OBJETADO- No. Guía 1144351750', 'OBJETADO- No. Guía 1144351751',
#        'OBJETADO- No. Guía 1144351747', 'OBJETADO- No. Guía 1144351748',
#        'OBJETADO- No. Guía 1144351735', 'OBJETADO- No. Guía 1144351736',
#        'OBJETADO- No. Guía 1144351744', 'OBJETADO- No. Guía 1145241410',
#        'DESISTIDO', 'OBJETADO- No. Guia 1145241486',
#        'OBJETADO- No. Guía 1145241412', 'OBJETADO- No. Guía 1145241411',
#        'OBJETADO- No. Guía 1145241409', 'OBJETADO- No. Guía 1145241431',
#        'OBJETADO- No. Guía 1145241415', 'OBJETADO- No. Guía 1145241417',
#        'OBJETADO- No.Guia 1145241487', 'OBJETADO- No. Guía 1145241420',
#        'OBJETADO- No. Guía 1145241419', 'OBJETADO- No. Guía 1145241418',
#        'OBJETADO- No. Guía 1145241421', 'OBJETADO- No. Guía 1145241422',
#        'OBJETADO- No. Guía 1145241491', 'OBJETADO- No. Guia 1145241488',
#        'OBJETADO- No. Guia 1147537578', 'OBJETADO- No. Guia 1147537621',
#        'OBJETADO- No. Guia 1147537619', 'OBJETADO- No. Guia 1147537620',
#        'OBJETADO- No. Guía 1148920458', 'OBJETADO- No. Guia 1147537603',
#        'OBJETADO- No. Guia 1147537602', 'OBJETADO- No. Guia 1148920465',
#        'OBJETADO- No. Guia 1147537601', 'OBJETADO- No. Guía 1147537593',
#        'OBJETADO- No. Guia 1147537600', 'OBJETADO- No. Guia 1147537599',
#        'OBJETADO- No. Guia 1147537597', 'OBJETADO- No. Guia 1147537596',
#        'OBJETADO- No. Guia 1147537595', 'OBJETADO- No. Guia 1147537594',
#        'OBJETADO- No. Guia 1147537614', 'OBJETADO- No. Guía 1147537588',
#        'OBJETADO- No. Guía 1148920340', 'OBJETADO- No. Guía 1148920341',
#        'OBJETADO- No. Guía 1148920354', 'OBJETADO- No. Guía 1148920350',
#        'OBJETADO- No. Guía 1148920351 ', 'OBJETADO- No. Guía 1148920342',
#        'OBJETADO- No. Guía 1148920343', 'OBJETADO- No. Guía 1148920223',
#        'OBJETADO- No. Guía 1148920357', 'OBJETADO- No. Guía 1148920358',
#        'OBJETADO- No. Guía 1148920238', 'OBJETADO- No. Guía 1148920356',
#        'OBJETADO- No. Guía 1148920359', 'OBJETADO- No. Guía 1148920232',
#        'OBJETADO- No. Guía 1148920237', 'OBJETADO- No. Guía 1148920229',
#        'OBJETADO- No. Guía 1148920227', 'OBJETADO- No. Guía 1148920364',
#        'OBJETADO- No. Guía 1148920370', 'OBJETADO- No. Guía 1148920367',
#        'OBJETADO- No. Guía 1148920369', 'OBJETADO- No. Guía 1148920372',
#        'OBJETADO- No. Guía 1148920374', 'OBJETADO- No. Guía 1148920375',
#        'OBJETADO- No. Guía 1148920371', 'OBJETADO- No. Guía 1148920373',
#        'OBJETADO- No. Guía 1149793863', 'OBJETADO- No. Guía 1149793959',
#        'OBJETADO- No. Guía 1148920252', 'OBJETADO- No. Guía 1148920236',
#        'OBJETADO- No. Guía 1148920251', 'CERRADO',
#        'OBJETADO- No. Guía 1148920239', 'OBJETADO- No. Guía 1148920247',
#        'OBJETADO- No. Guía 1148920240', 'OBJETADO- No. Guía 1148920241',
#        'OBJETADO- No. Guía 1148920242', 'OBJETADO- No. Guía 1148920243',
#        'OBJETADO- No. Guía 1148920244', 'OBJETADO- No. Guía 1148920245',
#        'OBJETADO- No. Guía 1149793838', 'OBJETADO- No Guía 1149793867',
#        'OBJETADO- No. Guía 1149793833', 'OBJETADO- No. Guía 1149793864',
#        'OBJETADO- No. Guía 1149793834', 'OBJETADO- No Guía 1150591953',
#        'OBJETADO- No Guía 1150591956', 'OBJETADO- No Guía 1150591954',
#        'OBJETADO- No Guía 1150592048', 'OBJETADO- No Guía 1150592037',
#        'OBJETADO- No Guía 1150591973', 'OBJETADO- No Guía 1150592052',
#        'OBJETADO- No Guía 1150592051', 'OBJETADO- No Guía 1150592060',
#        'OBJETADO- No Guía 1150591936', 'OBJETADO- No Guía 1150592202',
#        'OBJETADO- No Guía 1150592201', 'OBJETADO- No. Guia 1150592584',
#        'OBJETADO- No. Guia 1150592588', 'OBJETADO- No. Guia 1150592578',
#        'OBJETADO- No. Guía 1144351733', 'OBJETADO- No. Guía 1144351740',
#        'OBJETADO- No. Guía 1145240416', 'OBJETADO- No. Guía 1144351746',
#        'OBJETADO- No. Guía 1145241413', 'OBJETADO- No. Guía 1145241493',
#        'OBJETADO- No. Guía 1145241425', 'OBJETADO- No. Guia 1145241784',
#        'OBJETADO- No. Guía 1145241433', 'OBJETADO- No. Guía 1145241429',
#        'OBJETADO- No. Guía 1145241428', 'OBJETADO- No. Guía 1145241427',
#        'OBJETADO- No.Guia 1145241485', 'OBJETADO- No.Guia 1145241495',
#        'OBJETADO- No.Guia 1145241492', 'PENDIENTE DOCUMENTOS',
#        'OBJETADO- No.Guia 1147537616', 'OBJETADO- No.Guia 1147537581',
#        'OBJETADO- No.Guia 1147537579', 'OBJETADO- No.Guia 1147537613',
#        'OBJETADO- No.Guia 1147537612', 'OBJETADO- No. Guía 1148920457',
#        'OBJETADO- No.Guia 1147537583', 'OBJETADO- No.Guia 1147537584',
#        'OBJETADO- No.Guia 1147537605', 'OBJETADO- No. Guía 1148920468',
#        'OBJETADO- No.Guia 1147537611', 'OBJETADO- No. Guía 1148920446',
#        'OBJETADO- No. Guía 1148920444', 'OBJETADO- No.Guia 1147537610',
#        'OBJETADO- No. Guía 1148920443', 'OBJETADO- No.Guia 1147537615',
#        'OBJETADO- No. Guía 1148920462', 'OBJETADO- No.Guia 1148920463',
#        'OBJETADO- No. Guía 1148920442', 'OBJETADO- No.Guia 1147537608',
#        'OBJETADO- No.Guia 1143537607', 'OBJETADO- No. Guía 1148920434',
#        'OBJETADO- No. Guía 1148920437', 'OBJETADO- No.Guia 1147537606',
#        'OBJETADO- No. Guía 1148920466', 'OBJETADO- No. Guía 1148920345',
#        'OBJETADO- No. Guía 1148920435', 'OBJETADO- No. Guía 1148920460',
#        'OBJETADO- No. Guía 1148920447', 'OBJETADO- No. Guía 1148920450',
#        'OBJETADO- No. Guía 1148920360', 'OBJETADO- No. Guía 1148920346',
#        'OBJETADO- No. Guía 1148920347', 'OBJETADO- No. Guía 1148920348',
#        'OBJETADO- No. Guía 1148920235', 'OBJETADO- No. Guía 1148920234',
#        'OBJETADO- No. Guía 1148920249', 'OBJETADO- No. Guía 1148920250',
#        'OBJETADO- No Guía 1149793870', 'OBJETADO- No Guía 1149793871',
#        'OBJETADO- No. Guía ', 'OBJETADO- No Guía 1149793963',
#        'OBJETADO- No Guía 1149793964', 'OBJETADO- No Guía 1149793868',
#        'OBJETADO- No. Guía 1148920260', 'OBJETADO- No. Guía 1149793835',
#        'OBJETADO- No Guía 1149793886', 'OBJETADO- No Guía 1149793994',
#        'OBJETADO- No. Guía 1149793836', 'OBJETADO- No. Guía 1149793837',
#        'OBJETADO- No Guía 1149793869', 'OBJETADO- No Guía 1149793995',
#        'OBJETADO- No Guía 1149793965', 'OBJETADO- No Guía 1149793991',
#        'OBJETADO- No Guía 1149793960', 'OBJETADO- No Guía 1149793961',
#        'OBJETADO- No Guía 1149793966', 'OBJETADO- No Guía 1149793967',
#        'OBJETADO- No Guía 1149793996', 'OBJETADO- No Guía 1149793993',
#        'OBJETADO- No Guía 1149793887', 'OBJETADO- No Guía 1149793968',
#        'OBJETADO- No Guía 1149793885', 'OBJETADO- No Guía 1149794046',
#        'OBJETADO- No Guía 1149793945', 'OBJETADO- No Guía 1149793969',
#        'OBJETADO- No Guía 1149793946', 'OBJETADO- Guía No. 1149794094',
#        'OBJETADO- No Guía 1149793884', 'OBJETADO- No Guía 1149793944',
#        'OBJETADO- No Guía 1149794052', 'OBJETADO- No Guía 1149794058',
#        'OBJETADO- No Guía 1149794077', 'OBJETADO- No Guía 11497940453',
#        'OBJETADO- Guía No. 1149794095', 'OBJETADO- No Guía 1149794078',
#        'OBJETADO- No Guía 1150591955', 'OBJETADO- No Guía 1150591972',
#        'OBJETADO- No Guía 1150591974', 'OBJETADO- No Guía 1150592036',
#        'OBJETADO- No. Guia 1150592583', 'OBJETADO- No Guía 1150592065',
#        'OBJETADO- No Guía 1150492176', 'OBJETADO- No Guía 1150592199',
#        'OBJETADO- No Guía 1150592360', 'OBJETADO- No. Guia 1150592585',
#        'OBJETADO- No Guía 1150592193', 'OBJETADO- No Guía 1150592358',
#        'PROCESO DE PAGO', 'OBJETADO- No Guía 1150592203',
#        'OBJETADO- No Guía 1150592361', 'OBJETADO- No. Guia 1150592576',
#        'OBJETADO- No. Guia 1150592579', 'OBJETADO- No. Guia 1150592694',
#        'OBJETADO- No. Guia 1150592695', 'OBJETADO- No. Guia 149794179',
#        'OBJETADO- No. Guia 149794172', 'OBJETADO- No. Guia 1150592592',
#        'OBJETADO- No. Guia 1150592593', 'OBJETADO- No. Guia 1150592691',
#        'OBJETADO- No. Guia 1150592689', 'OBJETADO- No. Guía 1144351762',
#        'OBJETADO- No. Guía 1144351765', 'OBJETADO- No. Guía 1144351738',
#        'OBJETADO- No. Guía 1144351761', 'OBJETADO- No. Guía 1144351766',
#        'OBJETADO- No. Guía 1147537604', 'OBJETADO- No. Guía 1145240423',
#        'OBJETADO- No. Guía 1144351760', 'OBJETADO- No. Guía 1145240426',
#        'OBJETADO- No. Guía 1145241407', 'OBJETADO- No. Guía 1145240415',
#        'OBJETADO- No. Guía 1145241432', 'OBJETADO- No. Guía 1148920361',
#        'OBJETADO- No. Guía 1145241426', 'OBJETADO- No.Guía 1145241483',
#        'OBJETADO- No.Guía 1147537587', 'OBJETADO- No.Guía 1147537585',
#        'OBJETADO- No. Guía 1145241494', 'OBJETADO- No. Guía 1147537586',
#        'OBJETADO- No. Guía 1148920439', 'OBJETADO- No. Guía 1148920440',
#        'OBJETADO- No. Guía 1148920461', 'OBJETADO- No. Guía 1148920470',
#        'OBJETADO- No. Guía 1148920459', 'OBJETADO- No. Guía 1148920448',
#        'OBJETADO- No. Guía 1148920449', 'OBJETADO- No. Guía 1148920451',
#        'OBJETADO- No. Guía 1148920344', 'OBJETADO- No. Guía 1148920365',
#        'OBJETADO- No. Guía 1148920366', 'OBJETADO- No. Guía 1148920225',
#        'OBJETADO- No. Guía 1148920224', 'OBJETADO- No. Guía 1148920230',
#        'OBJETADO- No. Guía 1148920226', 'OBJETADO- No. Guía 1148920228',
#        'OBJETADO- No. Guía 1148920246', 'OBJETADO- No. Guía 1148920259',
#        'OBJETADO- No Guía 1149793882', 'OBJETADO- No Guía 1149793881',
#        'OBJETADO- No Guía 1149793883', 'OBJETADO- No Guía 1149794048',
#        'OBJETADO- No Guía 1149793943', 'OBJETADO- No Guía 1149794047',
#        'OBJETADO- No Guía 1149793888', 'OBJETADO- No Guía 1149794049',
#        'OBJETADO- Guía No. 1149794092', 'OBJETADO- No Guía 1149794037',
#        'OBJETADO- Guía No. 1149794091', 'OBJETADO- No Guía 1149794950',
#        'OBJETADO- No Guía 1149794040', 'OBJETADO- No Guía 1149794041',
#        'OBJETADO- No Guía 1149794038', 'OBJETADO- No Guía 1149794039',
#        'OBJETADO- No Guía 1149794042', 'OBJETADO- No Guía 1149794057',
#        'OBJETADO- Guía No. 1149794093', 'OBJETADO- No Guía 1149794074',
#        'OBJETADO- No Guía 1149794075', 'OBJETADO- No Guía 1149794076',
#        'OBJETADO- No Guía 1150591906', 'OBJETADO- No Guía 1149794079',
#        'OBJETADO- No Guía 1150591907', 'OBJETADO- No Guía 1150591910',
#        'OBJETADO- No Guía 1150591952', 'OBJETADO- Guía No. 1150591970',
#        'OBJETADO- Guía No. 1150591971', 'OBJETADO- No Guía 1150592047',
#        'OBJETADO- Guía No. 1150592034', 'OBJETADO- No Guía 1150592050',
#        'OBJETADO- No Guía 1150592049', 'OBJETADO- No Guía 1150592035',
#        'OBJETADO- No Guía 1150592061', 'OBJETADO- No Guía 1150592066',
#        'OBJETADO- No Guía 1150492175', 'OBJETADO- No Guía 1150592067',
#        'OBJETADO- No Guía 1150592190', 'OBJETADO- No Guía 1150592191',
#        'OBJETADO- No. Guia 1150592699', 'OBJETADO- No Guía 1150592192',
#        'OBJETADO- No Guía 1150592200', 'OBJETADO- No Guía 1150592196',
#        'OBJETADO- No Guía 1150592197', 'OBJETADO- No Guía 1150592198',
#        'OBJETADO- No Guía 1150592359', 'OBJETADO- No Guía 1150591937',
#        'OBJETADO- No Guía 1150592362', 'OBJETADO- No Guía 1150592357',
#        'OBJETADO- No. Guia 1150592586', 'OBJETADO- No Guía 1150592355',
#        'OBJETADO- No Guía 1150592352', 'OBJETADO- No Guía 1150592363',
#        'OBJETADO- No Guía 1150592356', 'OBJETADO- No Guía 1150592354',
#        'OBJETADO- No Guía 1150592353', 'OBJETADO- No. Guia 1150592582',
#        'OBJETADO- No. Guia 1150592581', 'OBJETADO- No. Guia 1150592580',
#        'OBJETADO- No. Guia 1150592577', 'OBJETADO- No. Guia 1150592589',
#        'OBJETADO- No. Guia 1150592590', 'OBJETADO- No. Guia 1150592591',
#        'OBJETADO- No. Guia 1150592690', 'OBJETADO- No. Guia 1150592693',
#        'OBJETADO- No. Guia 115059696', 'OBJETADO- No. Guía 1150592700',
#        'OBJETADO- No. Guía 1151571992', 'OBJETADO- No. Guía 1151572184',
#        'OBJETADO- No. Guía 1151571993', 'OBJETADO- No. Guía 1151572007',
#        'ACEPTACION DE CIFRA', 'APROBACIÓN DE CIFRA ',
#        'PENDIENTE ENVIAR A PAGO', 'PROCESO DE AJUSTE',
#        'PROCESO DE INSPECCIÓN', 'OBJETADO- No. Guía 1151572236',
#        'OBJETADO- No. Guía 1151572252', 'APROBACIÓN DE OBJECIÓN', nan],
#       dtype=object)

# %% [markdown]
# Al revisar los valores únicos de 'observacion_1', encontramos que para el caso del valor categoríco <b>'OBJETADO'</b>, tiene asociado un número de guía, aunque en la aplicación sólo puede escoger el valor <b>'OBJETADO'</b>. Lo que se va a realizar es, reemplazar todos los objetados con algún número de Guía por sólo la leyenda <b>'OBJETADO'</b>

# %%
#Reemplazo todos los valores que contienen la palabra objetado, por sólo la palabra 'OBJETADO'
mask = df_migrar['observacion_1'].str[:8] == 'OBJETADO'
df_migrar['observacion_1'].mask(mask,'OBJETADO', inplace = True)
df_migrar['observacion_1'].value_counts()
# Out:
# PAGADO                     887
# OBJETADO                   333
# DESISTIDO                   12
# PROCESO DE INSPECCIÓN       12
# PROCESO DE PAGO             10
# PENDIENTE DOCUMENTOS         8
# CERRADO                      7
# PROCESO DE AJUSTE            4
# APROBACIÓN DE CIFRA          4
# PENDIENTE ENVIAR A PAGO      3
# ACEPTACION DE CIFRA          1
# APROBACIÓN DE OBJECIÓN       1
# Name: observacion_1, dtype: int64

# %% [markdown]
# el campo <b>observacion_1</b> fue ajustado.
# #### Objetivo 2, completado
#
# ## Finalización: En esta parte se creará el archivo de Excel en el cuál se tendrá la base de datos limpia y lista para realizar la migración. En este punto el Notebook termina.

# %%
#A continuación vamos a generar el archivo de excel que vamos a migrar.
df_migrar.to_excel("migracion_chubb.xlsx")
